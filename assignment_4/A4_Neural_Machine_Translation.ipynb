# %% [markdown]
# <a href="https://colab.research.google.com/github/OssamaTammam/CCE456-NaturalLanguageProcessing/blob/master/assignment_4/A4_Neural_Machine_Translation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notebook for Programming in Problem 4
# Welcome to the programming portion of the assignment! Each assignment throughout the semester will have a written portion and a programming portion. We will be using [Google Colab](https://colab.research.google.com/notebooks/intro.ipynb#recent=true), so if you have never used it before, take a quick look through this introduction: [Working with Google Colab](https://docs.google.com/document/d/1LlnXoOblXwW3YX-0yG_5seTXJsb3kRdMMRYqs8Qqum4/edit?usp=sharing).

# %% [markdown]
# ## Learning Objectives
# In this problem, we will use [PyTorch](https://pytorch.org/) to implement a sequence-to-sequence (seq2seq) transformer model to build a nerual machine translation (NMT) system, which translates from French to English.

# %% [markdown]
# ## Writing Code
# Look for the keyword "TODO" and fill in your code in the empty space.
# You can edit code in the other parts of the notebook too, which can be useful for debugging, but be careful to avoid breaking the provided code.

# %% [markdown]
# ## Installing Packages
#
# Install PyTorch using pip. See [https://pytorch.org/](https://pytorch.org/) if you want to install it on your computer.
# In addition, we will also be needing [huggingface](https://huggingface.co/)'s `transformers` and `datasets` libraries, and [nltk](https://www.nltk.org/) to compute the BLEU score.

# %%
# Pytorch is typically already installed in Google Colab (uncomment to install):
# !pip install torch==1.8.0
# or for GPU support:
# !pip install torch==1.8.0+cu111 -f https://download.pytorch.org/whl/torch_stable.html
# !pip install transformers==4.27.0
# !pip install datasets==2.10.0
# NLTK is typically also already installed in Google Colab (uncomment to install):
# !pip install nltk==3.8.1
# Out:
# Requirement already satisfied: transformers==4.27.0 in /usr/local/lib/python3.10/dist-packages (4.27.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers==4.27.0) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers==4.27.0) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.27.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.27.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.27.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.27.0) (2024.2.2)
# Requirement already satisfied: datasets==2.10.0 in /usr/local/lib/python3.10/dist-packages (2.10.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (1.25.2)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (14.0.2)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (0.3.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (4.66.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (3.9.5)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (0.20.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (24.0)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (0.18.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.10.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.10.0) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.10.0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.10.0) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.10.0) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.10.0) (4.0.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets==2.10.0) (3.14.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets==2.10.0) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.10.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.10.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.10.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.10.0) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets==2.10.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets==2.10.0) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets==2.10.0) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets==2.10.0) (1.16.0)

# %% [markdown]
# ## Download NMT data

# %% [markdown]
# We first download the data for NMT, which contains pairs of parallel sentences.

# %%
# !wget --quiet https://princeton-nlp.github.io/cos484/assignments/a4/resources.zip
# !unzip -qo resources.zip

# %% [markdown]
# ## Data preprocessing
# In this section we will write code to load and tokenize the data for NMT.
#
#
# The parallel data is provided as huggingface datasets, one for each split of `train`, `validation` and `test`. We load it via the `load_from_disk` method and inspect its features. If you'd like to know more about these dataset objects, have a look at [this tutorial](https://huggingface.co/docs/datasets/access).

# %%
from datasets import load_from_disk
raw_text_datasets = load_from_disk("resources/parallel_en_fr_corpus")
print("Summary of splits:", raw_text_datasets)
print("First training example:", raw_text_datasets["train"][0])
# Out:
# Summary of splits: DatasetDict({
#     train: Dataset({
#         features: ['text_en', 'text_fr'],
#         num_rows: 8701
#     })
#     validation: Dataset({
#         features: ['text_en', 'text_fr'],
#         num_rows: 485
#     })
#     test: Dataset({
#         features: ['text_en', 'text_fr'],
#         num_rows: 486
#     })
# })
# First training example: {'text_en': 'i m tough .', 'text_fr': 'je suis dure .'}

# %% [markdown]
# You are also provided with two pre-trained tokenizers for the source and target languages respectively, which we can load with the hugginface transfomers library. [This tutorial](https://huggingface.co/docs/transformers/preprocessing#natural-language-processing) provides an introduction to using pre-trained tokenizers and the powerful `AutoTokenizer` class. The tokenizers are based on byte-pair encodings which break words into smaller units. This is aimed at reducing the sparsity of words, as subwords can be shared between different rare words. If you are interested in learning more, see the paper [Neural Machine Translation of Rare Words with Subword Units](https://www.aclweb.org/anthology/P16-1162.pdf).

# %%
from transformers import AutoTokenizer
source_tokenizer = AutoTokenizer.from_pretrained("resources/tokenizer_fr")
target_tokenizer = AutoTokenizer.from_pretrained("resources/tokenizer_en")

print("Vocab size of source language:", source_tokenizer.vocab_size)
print("Vocab size of target language:", target_tokenizer.vocab_size)

# As a demonstration, we will the following English sentence to tokens.
example_sentence = "we have an example"
tokenizer_output = target_tokenizer(example_sentence)
print("\n*** Example ***")
print("Example sentence:", example_sentence)
print("Tokenizer output:", tokenizer_output)

# We convert every token id to its associated string, but find the special character ▁ which indicates the beginning of a word.
# Note that very common words are represented by a single token, while others are split into subunits due to the small vocab size.
# Also note that †he tokenizer already adds special tokens to the beginning and end of the sentence.
decoded_sequence = [target_tokenizer.decode(token) for token in tokenizer_output["input_ids"]]
print("Tokens:", decoded_sequence)

# By replacing the special character ▁ with whitespace, we can reconstruct a legibile sentence,
# which differs from the original example by special tokens, includings <unk> tokens, and minor whitespace differences.
reconstructed = "".join(decoded_sequence).replace("▁", " ")
print("Reconstructed sentence", reconstructed)
# Out:
# Vocab size of source language: 3200
# Vocab size of target language: 3200
#
# *** Example ***
# Example sentence: we have an example
# Tokenizer output: {'input_ids': [1, 64, 324, 103, 266, 1490, 92, 2], 'token_type_ids': [0, 0, 0, 0, 0, 0, 0, 0], 'attention_mask': [1, 1, 1, 1, 1, 1, 1, 1]}
# Tokens: ['<s>', '▁we', '▁have', '▁an', '▁ex', 'amp', 'le', '</s>']
# Reconstructed sentence <s> we have an example</s>

# %% [markdown]
# We now want to convert the entire dataset to token ids.
# Specifically, we want to use the tokenizers to create a dataset with
# features "encoder_input_ids" and "decoder_input_ids", which both have type `List[int]`
# and which will later be the inputs to our encoder-decoder model. We will implement this using the powerful `map` function. You can find its API reference [here](https://huggingface.co/docs/datasets/v2.10.0/en/package_reference/main_classes#datasets.Dataset.map).

# %%
from typing import Dict, List

def map_example(example: Dict[str, str]) -> Dict[str, List[int]]:
    # TODO: Tokenize the source and target text for an entry in the parallel dataset
    # and return a dictionary with the keys "encoder_input_ids" and "decoder_input_ids".
    # You can use `source_tokenizer` and `target_tokenizer`

    encoder_input_ids = source_tokenizer.encode(example['text_fr'], truncation=True, padding="max_length")
    decoder_input_ids = target_tokenizer.encode(example['text_en'], truncation=True, padding="max_length")

    return {
        "encoder_input_ids": encoder_input_ids,
        "decoder_input_ids": decoder_input_ids
    }

# When mapped is applied to the DatasetDict object, it will apply `map` separately to each split.
tokenized_datasets = raw_text_datasets.map(map_example, batched=False)

# The `remove_columns` removes the existing text features from the new dataset, as they are no longer needed.
tokenized_datasets = tokenized_datasets.remove_columns(raw_text_datasets.column_names["train"])

# Sanity checks on the new dataset
assert set(tokenized_datasets.column_names["train"]) == {"decoder_input_ids", "encoder_input_ids"}
assert len(tokenized_datasets["train"]) == len(raw_text_datasets["train"])
# Out:
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /content/resources/parallel_en_fr_corpus/train/cache-08ec6dfbf1d256e6.arrow
# Map:   0%|          | 0/485 [00:00<?, ? examples/s]
# Asking to pad to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no padding.
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Asking to pad to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no padding.
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /content/resources/parallel_en_fr_corpus/test/cache-030ec1b7cf9e030c.arrow

# %% [markdown]
# ## Transformer model for NMT

# %% [markdown]
# We will now implement a encoder-decoder transformer model.
# We already provide code for the Feedforward Layers and Transformer Blocks, but you will have to implement the MultiHeadAttention and Embedding layer from scratch, as well as registering all the layers in the final EncoderDecoderModel. Pay attention to doc-strings and typing information to understand the context and purpose of each missing code block!

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

import math
from typing import Optional, Dict, List, Tuple

# %%
class MultiHeadAttention(nn.Module):
    def __init__(self,
                 hidden_size: int,
                 num_attention_heads: int,
                 is_causal_attention: bool = False,
                 is_cross_attention: bool = False):
        """Defines a flexible multi-head attention layer.

        This layer should define parameters for the query, key and value projections, as well as the output projection,
        and implement the following steps:
        (1) Project the input vectors using query projection and key projection matrices.
        (2) Compute the head-wise attention scores scaled by 1/sqrt(head_dim)
        (3) Perform appropriate masking to the attention scores using key_padding_mask and optionally causal attention.
        (4) Normalize the head-wise attention scores using softmax.
        (5) Compute the value projections and then aggregate using the normalized attention scores.
        (6) Use the output projection to obtain the final output vectors.
        When is_cross_attention is True, the key and value projections are computed from the encoder outputs.
        Note that we do not use attention weight dropout in this implementation.

        Args:
            hidden_size: The dimensionality of the input vectors.
            num_attention_heads: The number of attention heads.
            is_causal_attention: Whether to use causal masking,
                    where tokens cannot attend to the future tokens on their right.
            is_cross_attention: Whether to use cross attention,
                    where we use different inputs for the key/value vs. query vectors.
        """
        super().__init__()
        assert hidden_size % num_attention_heads == 0, "The hidden size must be divisible by the number of attention heads."
        self.head_dim = hidden_size // num_attention_heads  # embedding dimension of query and key vectors per head

        # TODO Initialize the module and its parameters here.
        # This module should be able to handle both full self-attention, causal masked self-attention and cross-attention.
        # IMPORTANT: You are not allowed to use `nn.MultiheadAttention` or `nn.functional.scaled_dot_product_attention`!

        # Initialize the module and its parameters here
        self.num_attention_heads = num_attention_heads
        self.hidden_size = hidden_size

        self.query_proj = nn.Linear(hidden_size, hidden_size)
        self.key_proj = nn.Linear(hidden_size, hidden_size)
        self.value_proj = nn.Linear(hidden_size, hidden_size)
        self.output_proj = nn.Linear(hidden_size, hidden_size)

        self.is_causal_attention = is_causal_attention
        self.is_cross_attention = is_cross_attention


    def causal_attention_mask(self,
                              sequence_length: int,
                              device: Optional[torch.device] = None) -> torch.FloatTensor:
        """Return a Float tensor that can be added to the (un-normalized) attention scores for causal masking.

        Args:
            sequence_length: width and height of the attention mask tensor.
            device: which torch device the resulting tensor should be on (important if you use GPU).

        Returns:
            A Float tensor of shape (1, 1, sequence_length, sequence_length) on device `device`,
            where the entries above the diagonal contain large negative values,
            which means that a query at position i can't attend to a key at position j>i.
        """

        # TODO Implement the forward function.
        # IMPORTANT: For full credit, you should not use python loops.
        #
        # Hint 1: You can pick an arbitrary large value (e.g., -10^{6}), but note that
        #         using `float("-inf")` might lead to numerical issues and 'nan' values during training.
        #
        # Hint 2: Useful pytorch functions for this are `torch.arange` or `torch.triu`.
        #
        # Hint 3: You can move the tensor you create to a device by calling `tensor.to(device)`
        #
        # You should use this function in `forward` and use the returned tensor to implement causal masking
        # by adding it to the un-normalized attention scores of shape (batch_size, num_heads, sequence_length, sequence_length),
        # as torch will handle broadcasting and expand the first two dimensions to batch size and num_heads.
        #
        # You will the masking tensor to be on the same device as the attention scores's device,
        # which you can via the attribute `tensor.device`.
        mask = torch.triu(torch.ones(sequence_length, sequence_length, device=device) * float('-inf'), diagonal=1)
        return mask.unsqueeze(0).unsqueeze(0)  # (1, 1, sequence_length, sequence_length)


    def forward(self,
                hidden_states: torch.FloatTensor,
                key_padding_mask: torch.BoolTensor,
                encoder_outputs: Optional[torch.FloatTensor] = None) -> Tuple[torch.FloatTensor, torch.FloatTensor]:
        """Computes scaled dot-product attention and returns the output of the attention layer.

        Args:
            hidden_states: Tensor of shape (batch_size, sequence_length, hidden_size) - the input vectors to the layer.
            key_padding_mask: Tensor of shape (batch_size, sequence_length) indicating which tokens are padding tokens.
                    A `True` entry means that this token should be ignored for the purpose of attention.
                    In the case of cross-attention, the tensor has shape (batch_size, encoder_sequence_length).
            encoder_outputs: Optional tensor of shape (batch_size, encoder_sequence_length, hidden_size).
                    The output vectors of the encoder and only passed if the layer performs cross-attention.

        Returns:
            A (layer_output, attention_weights) where layer_output is a tensor of shape (batch_size, sequence_length, hidden_size)
            and attention_weights are the normalized attention scores in the form of
            a tensor of shape (batch_size, num_attention_heads, number_of_query_tokens, number_of_key_tokens).
        """

        # TODO Implement the forward function.
        # IMPORTANT: For full credit, you should not use python loops. Furthermore,
        #            you are not allowed to use `nn.MultiheadAttention` or `nn.functional.scaled_dot_product_attention`!
        #
        # Hint 1: Use `torch.reshape` to add a new axis for the attention head,
        #         which will allow you to process all attention heads in parallel.
        #
        # Hint 2: You can use `torch.transpose` to swap the order of two axes,
        #         As the attention head dimension should be next to the batch size,
        #         see the shape of the output attention weights.
        #
        # Hint 3: `torch.bmm(matrix1, matrix2)` is useful for computing batched matrix multiplications
        #         If matrix1 has shape (B, M, N) and matrix2 has shape (B, N, P),
        #         it performs `B` matrix multiplications and outputs a tensor of shape (B, M, P).
        #         Alternatively, `torch.einsum` should be very useful.
        #         (We really encourage you to check out the documentation of `torch.einsum`,
        #         it can really make your life easier here.)

        # Determine the key and value projections
        if self.is_cross_attention and encoder_outputs is not None:
            keys = self.key_proj(encoder_outputs)
            values = self.value_proj(encoder_outputs)
        else:
            keys = self.key_proj(hidden_states)
            values = self.value_proj(hidden_states)

        # Project the hidden states to queries
        queries = self.query_proj(hidden_states)

        # Reshape for multi-head attention
        batch_size, seq_length, _ = hidden_states.size()
        queries = queries.view(batch_size, seq_length, self.num_attention_heads, self.head_dim).transpose(1, 2)
        keys = keys.view(batch_size, -1, self.num_attention_heads, self.head_dim).transpose(1, 2)
        values = values.view(batch_size, -1, self.num_attention_heads, self.head_dim).transpose(1, 2)

        # Compute the attention scores
        attention_scores = torch.matmul(queries, keys.transpose(-1, -2)) / (self.head_dim ** 0.5)

        # Apply the key padding mask
        if key_padding_mask is not None:
            attention_scores = attention_scores.masked_fill(key_padding_mask.unsqueeze(1).unsqueeze(2), float('-inf'))

        # Apply causal mask if needed
        if self.is_causal_attention:
            seq_length = attention_scores.size(-1)
            causal_mask = self.causal_attention_mask(seq_length, device=attention_scores.device)
            attention_scores = attention_scores + causal_mask

        # Normalize the attention scores
        attention_weights = F.softmax(attention_scores, dim=-1)

        # Compute the attention output
        attention_output = torch.matmul(attention_weights, values)

        # Reshape and combine attention heads
        attention_output = attention_output.transpose(1, 2).contiguous().view(batch_size, seq_length, self.hidden_size)

        # Apply the output projection
        layer_output = self.output_proj(attention_output)

        return layer_output, attention_weights

# %% [markdown]
# Before we move on to the other modules, you should implement a sanity check for your attention implementation:
# 1. We check the dimensions of the output of the layer and
# 2. We plot the attention weights to some toy embedding inputs.
# We assume that the last token in the encoder and the last two tokens in the decoder are pad tokens.

# %%
import matplotlib.pyplot as plt

embed_dim = 8
num_heads = 2
batch_size = 1
encoder_seq_length = 5
decoder_seq_length = 7

encoder_outputs = torch.randn(batch_size, encoder_seq_length, embed_dim)
decoder_inputs = torch.randn(batch_size, decoder_seq_length, embed_dim)

encoder_padding_mask = torch.zeros(batch_size, encoder_seq_length, dtype=torch.bool)
encoder_padding_mask[:, -1] = True # The last encoder token is a padding tokens

decoder_padding_mask = torch.zeros(batch_size, decoder_seq_length, dtype=torch.bool)
decoder_padding_mask[:, -2:] = True # The last two decoder tokens are padding token


cross_attention = MultiHeadAttention(embed_dim, num_heads, is_cross_attention=True)
causal_attention = MultiHeadAttention(embed_dim, num_heads, is_causal_attention=True)

cross_attention_out, cross_attention_weights = cross_attention(decoder_inputs, encoder_padding_mask, encoder_outputs)
causal_attention_out, causal_attention_weights = causal_attention(decoder_inputs, decoder_padding_mask)

# Make sure your outputs have the right hapes
assert cross_attention_out.shape == (batch_size, decoder_seq_length, embed_dim)
assert cross_attention_weights.shape == (batch_size, num_heads, decoder_seq_length, encoder_seq_length)
assert causal_attention_out.shape == (batch_size, decoder_seq_length, embed_dim)
assert causal_attention_weights.shape == (batch_size, num_heads, decoder_seq_length, decoder_seq_length)

# Check that the attention weights are normalized
assert torch.isclose(cross_attention_weights.sum(dim=-1), torch.tensor(1.0)).all()
assert torch.isclose(causal_attention_weights.sum(dim=-1), torch.tensor(1.0)).all()

# Check if the attention masking works
assert torch.isclose(cross_attention_weights[:,:,:,-1], torch.tensor(0.0)).all()
assert torch.isclose(causal_attention_weights[:,:,:,-2:], torch.tensor(0.0)).all()
assert torch.isclose(causal_attention_weights[:,:,2,3:], torch.tensor(0.0)).all()


import matplotlib.pyplot as plt

def plot_attention_matrix(attention_matrix, title):
    """Creates a new figure and plots the normalized attention weights as a heatmap.

    This should provide a colorbar for the scale of the heatmap and label the axes "query token position" and "key token position".
    Args:
        attention_matrix: A numpy array of shape (number_of_query_tokens, number_of_key_tokens)
        title: The title of the plot.
    """
    # TODO Implement this function
    plt.figure(figsize=(8, 6))
    plt.imshow(attention_matrix, cmap='viridis')
    plt.colorbar()
    plt.title(title)
    plt.xlabel('key token position')
    plt.ylabel('query token position')
    plt.show()

plot_attention_matrix(cross_attention_weights[0,0].detach().numpy(), "cross-attention, head 1")
plot_attention_matrix(cross_attention_weights[0,1].detach().numpy(), "cross-attention, head 2")
plot_attention_matrix(causal_attention_weights[0,0].detach().numpy(), "causal self-attention, head 1")
plot_attention_matrix(causal_attention_weights[0,1].detach().numpy(), "causal self-attention, head 2")

# %%
class TransformerEmbeddings(nn.Module):
    def __init__(self, vocab_size: int, hidden_size: int, max_sequence_length: int):
        """Defines the embedding layer with learnt positional embeddings.

        This layer defines both the token embeddings and positional embeddings,
        which are added together to form the final embedding.

        Args:
            vocab_size: The size of the vocabulary,
                    used to define the size of the token embedding table.
            hidden_size: The dimensionality of the embedding space for both token embeddings and positional embeddings.
            max_sequence_length: The maximum sequence length of the input sequences,
                    used to define the size of the position embedding table.

        Note that this implementation does not use dropout on the embeddings
        and uses learnt positional embeddings instead of sinusoidal embeddings.
        """
        super().__init__()

        # TODO Initialize the module and its parameters here.
        # You should use `nn.Embedding` for both token embeddings and positional embeddings

         # Initialize token embeddings
        self.token_embeddings = nn.Embedding(vocab_size, hidden_size)

        # Initialize positional embeddings
        self.position_embeddings = nn.Embedding(max_sequence_length, hidden_size)


    def compute_logits(self, decoder_output: torch.FloatTensor) -> torch.FloatTensor:
        """Computes the logits for the next token prediction given the decoder output.

        Args:
            decoder_output: Tensor of shape (batch_size, sequence_length, hidden_size) - the output of the decoder.

        Returns:
            Tensor of shape (batch_size, sequence_length, vocab_size) containing the logits for the next token prediction.
        """

        # TODO Implement this function
        # Hint: you can access the weight parameter matrix via .weight of an nn.Embedding module:
        # Example:
        # ```embeddings = nn.Embedding(num_embeddings, embedding_dim)
        # assert list(embeddings.weight.shape) == [num_embeddings, embedding_dim]```
        # torch.matmul or F.linear may also be useful here.

        logits = torch.matmul(decoder_output, self.token_embeddings.weight.t())
        return logits

    def forward(self, input_ids: torch.LongTensor) -> torch.FloatTensor:
        """Computes the embeddings for the input tokens.

        Args:
            input_ids: Tensor of shape (batch_size, sequence_length) containing the input token ids.

        Returns:
            Tensor of shape (batch_size, sequence_length, hidden_size) containing
                    the sum of token embeddings and position embeddings for the input tokens.
        """

        # TODO Implement the forward pass of the embedding layer.
        # IMPORTANT: For full credit, you should not use python loops!

        batch_size, sequence_length = input_ids.size()

        # Get token embeddings
        token_embeds = self.token_embeddings(input_ids)  # Shape: (batch_size, sequence_length, hidden_size)

        # Generate position indices
        position_ids = torch.arange(sequence_length, device=input_ids.device)
        position_ids = position_ids.unsqueeze(0).expand(batch_size, sequence_length)  # Shape: (batch_size, sequence_length)

        # Get positional embeddings
        position_embeds = self.position_embeddings(position_ids)  # Shape: (batch_size, sequence_length, hidden_size)

        # Sum token and positional embeddings
        embeddings = token_embeds + position_embeds

        return embeddings

# %%
class TransformerBlock(nn.Module):
    def __init__(self,
                 hidden_size: int,
                 intermediate_size: int,
                 num_attention_heads: int,
                 hidden_dropout_prob: float,
                 is_decoder: bool = False):
        """Defines a single Transformer block, which can be either for the encoder or the decoder.

        Args:
            hidden_size: The dimensionality of the input and output vectors of this layer.
            intermediate_size: The intermediate size of the feedforward layers.
            num_attention_heads: The number of attention heads.
            hidden_dropout_prob: The dropout probability for the hidden states.
            is_decoder: Whether this block is part of the decoder.
        """
        super().__init__()

        self.is_decoder = is_decoder
        self.self_attention = MultiHeadAttention(hidden_size, num_attention_heads, is_causal_attention=is_decoder)
        self.self_attention_layer_norm = nn.LayerNorm(hidden_size)

        if is_decoder:
            self.cross_attention = MultiHeadAttention(hidden_size, num_attention_heads, is_cross_attention=True)
            self.cross_attention_layer_norm = nn.LayerNorm(hidden_size)

        self.feedforward = nn.Sequential(
            nn.Linear(hidden_size, intermediate_size),
            nn.ReLU(),
            nn.Linear(intermediate_size, hidden_size),
            nn.Dropout(hidden_dropout_prob))
        self.feedforward_layer_norm = nn.LayerNorm(hidden_size)

    def forward(self,
                hidden_states: torch.FloatTensor,
                padding_mask: torch.BoolTensor,
                encoder_outputs: Optional[torch.FloatTensor] = None,
                encoder_padding_mask: Optional[torch.BoolTensor] = None) -> torch.FloatTensor:
        """Defines a single Transformer block, either for the encoder or the decoder.

        Args:
            hidden_states: Tensor of shape (batch_size, sequence_length, hidden_size) - the outputs from the previous layer.
            padding_mask: Tensor of shape (batch_size, sequence_length) indicating which tokens are padding tokens.
                    A `True` entry means that this token should be ignored for the purpose of attention.
            encoder_outputs: Optional tensor of shape (batch_size, encoder_sequence_length, hidden_size),
                    which are the output vectors of the encoder. This argument is only used by decoder blocks.
            encoder_padding_mask: Optional tensor of shape (batch_size, encoder_sequence_length) indicating
                    which encoder tokens are padding tokens. This argument is only used in decoder blocks.
                    A `True` entry means that this token should be ignored for the purpose of attention.

        """
        hidden_states = self.self_attention(hidden_states, padding_mask)[0] + hidden_states
        hidden_states = self.self_attention_layer_norm(hidden_states)

        if self.is_decoder:
            hidden_states = self.cross_attention(hidden_states, encoder_padding_mask, encoder_outputs)[0] + hidden_states
            hidden_states = self.cross_attention_layer_norm(hidden_states)

        hidden_states = self.feedforward(hidden_states) + hidden_states
        hidden_states = self.feedforward_layer_norm(hidden_states)
        return hidden_states

# %%
class EncoderDecoderModel(nn.Module):
    def __init__(self,
                 source_vocab_size: int,
                 target_vocab_size: int,
                 hidden_size: int,
                 intermediate_size: int,
                 num_attention_heads: int,
                 num_encoder_layers: int,
                 num_decoder_layers: int,
                 max_sequence_length: int,
                 hidden_dropout_prob: float):
        """A encoder-decoder transformer model which can be used for NMT.

        Args:
            source_vocab_size: The size of the source vocabulary.
            target_vocab_size: The size of the target vocabulary.
            hidden_size: The dimensionality of all input and output embeddings.
            intermediate_size: The intermediate size in the feedforward layers.
            num_attention_heads: The number of attention heads in each multi-head attention modules.
            num_encoder_layers: The number of transformer blocks in the encoder.
            num_decoder_layers: The number of transformer blocks in the decoder.
            max_sequence_length: The maximum sequence length that this model can handle.
            hidden_dropout_prob: The dropout probability in the hidden state in each block.
        """

        super().__init__()
        # TODO Register the input embedding modules and the encoder and decoder blocks.
        # You should use the TransformerBlock and TransformerEmbeddings sub-modules.
        #
        # Hint: Check out `nn.ModuleList` to register a variable number of sub-modules.

        # Initialize source language embedding
        self.source_embeddings = TransformerEmbeddings(source_vocab_size, hidden_size, max_sequence_length)

        # Initialize target language embedding
        self.target_embeddings = TransformerEmbeddings(target_vocab_size, hidden_size, max_sequence_length)

        # Initialize encoder blocks
        self.encoder_blocks = nn.ModuleList([
            TransformerBlock(hidden_size, intermediate_size, num_attention_heads, hidden_dropout_prob)
            for _ in range(num_encoder_layers)
        ])

        # Initialize decoder blocks
        self.decoder_blocks = nn.ModuleList([
            TransformerBlock(hidden_size, intermediate_size, num_attention_heads, hidden_dropout_prob, is_decoder=True)
            for _ in range(num_decoder_layers)
        ])

    def forward_encoder(self, input_ids: torch.LongTensor, padding_mask: torch.BoolTensor) -> torch.FloatTensor:
        """Implement the forward pass of the encoder.

        Args:
            input_ids: tensor of shape (batch_size, sequence_length) containing the input token ids to the encoder.
            padding_mask: tensor of shape (batch_size, sequence_length) indicating which encoder tokens are padding tokens (`True`)
                    and should be ignored in self-attention computations.

        Returns:
            Tensor of shape (batch_size, sequence_length, hidden_size) containing the output embeddings of the encoder.
        """

        # TODO Implement this function

        # Get source language embeddings
        embeddings = self.source_embeddings(input_ids)

        # Forward pass through encoder blocks
        encoder_output = embeddings
        for encoder_block in self.encoder_blocks:
            encoder_output = encoder_block(encoder_output, padding_mask)

        return encoder_output

    def forward_decoder(self,
                        input_ids: torch.LongTensor,
                        padding_mask: torch.BoolTensor,
                        encoder_outputs: torch.FloatTensor,
                        encoder_padding_mask: torch.BoolTensor) -> torch.FloatTensor:
        """Implement the forward pass of the decoder.

        Args:
            input_ids: Tensor of shape (batch_size, sequence_length) containing the input token ids to the decoder.
            padding_mask: Tensor of shape (batch_size, sequence_length) indicating which decoder tokens are padding tokens (`True`)
                    and should be ignored in self-attention computations.
            encoder_outputs: Tensor of shape (batch_size, encoder_sequence_length, hidden_size) containing the output embeddings of the encoder.
            encoder_padding_mask: Tensor of shape (batch_size, encoder_sequence_length) indicating which encoder tokens are padding tokens (`True`)
                    and should be ignored in cross-attention computations.

        Returns:
            Tensor of shape (batch_size, sequence_length, target_vocabulary_size)
            containing the logits for predicting the next token in the target sequence.
        """

        # TODO Implement this function

        # Get target language embeddings
        embeddings = self.target_embeddings(input_ids)

        # Forward pass through decoder blocks
        decoder_output = embeddings
        for decoder_block in self.decoder_blocks:
            decoder_output = decoder_block(decoder_output, padding_mask, encoder_outputs, encoder_padding_mask)

        # Compute logits
        logits = self.target_embeddings.compute_logits(decoder_output)
        return logits

    def forward(self, encoder_input_ids, encoder_padding_mask, decoder_input_ids, decoder_padding_mask):
        encoder_outputs = self.forward_encoder(encoder_input_ids, encoder_padding_mask)
        decoder_logits = self.forward_decoder(decoder_input_ids, decoder_padding_mask, encoder_outputs, encoder_padding_mask)
        return decoder_logits

# %% [markdown]
# ## Train the model
#
# In this section, we train the seq2seq model on the parallel tokenized corpus.
# Before you start training models, you should implement and test the model and its sub-modules, especially the attention.
#
# First, we implement a `collate` function, which takes a list of examples from the dataset and forms a batch,
# consisting of padded encoder and decoder input ids, as well as encoder and decoder padding masks.

# %%
def collate_fn(examples: List[Dict[str, List[int]]]) -> Dict[str, torch.Tensor]:
    """Collates a list of variable length sequences from the dataset into a batch of pytorch tensors with padding."""

    encoder_sequence_length = max(len(example["encoder_input_ids"]) for example in examples)
    decoder_sequence_length = max(len(example["decoder_input_ids"]) for example in examples)
    batch_size = len(examples)

    encoder_input_ids = torch.full((batch_size, encoder_sequence_length),
                                   fill_value=source_tokenizer.pad_token_id,
                                   dtype=torch.int64)
    encoder_padding_mask = torch.ones((batch_size, encoder_sequence_length),
                                      dtype=torch.bool)

    decoder_input_ids = torch.full((batch_size, decoder_sequence_length),
                                   fill_value=target_tokenizer.pad_token_id,
                                   dtype=torch.int64)
    decoder_padding_mask = torch.ones((batch_size, decoder_sequence_length),
                                      dtype=torch.bool)

    for i, example in enumerate(examples):
        encoder_input_ids[i, :len(example["encoder_input_ids"])] = torch.tensor(example["encoder_input_ids"])
        encoder_padding_mask[i, :len(example["encoder_input_ids"])] = False

        decoder_input_ids[i, :len(example["decoder_input_ids"])] = torch.tensor(example["decoder_input_ids"])
        decoder_padding_mask[i, :len(example["decoder_input_ids"])] = False

    return {"encoder_input_ids": encoder_input_ids,
            "encoder_padding_mask": encoder_padding_mask,
            "decoder_input_ids": decoder_input_ids,
            "decoder_padding_mask": decoder_padding_mask}

# %% [markdown]
# Next, we provide a simple training loop.

# %%
import time
import math

def compute_loss_per_token(model, batch):
    logits = model(**batch)

    valid_label_mask = ~(batch["decoder_padding_mask"][:,1:])
    labels = batch["decoder_input_ids"][:,1:][valid_label_mask]
    logits = logits[:,:-1][valid_label_mask]

    return F.cross_entropy(logits, labels, reduction='none')


def evaluate_perplexity(model, dataset, batch_size=32, device="cpu"):
    model.eval()

    dev_loader = torch.utils.data.DataLoader(
        dataset, batch_size=batch_size, shuffle=False, collate_fn=collate_fn)

    num_tokens = loss_sum = 0

    # no_grad() signals backend to throw away all gradients
    with torch.no_grad():
        for batch in dev_loader:
            # Move tensors in batch to device
            for key in batch:
                batch[key] = batch[key].to(device)

            token_losses = compute_loss_per_token(model, batch)

            loss_sum += token_losses.sum()
            num_tokens += token_losses.numel()

        dev_ppl = (loss_sum / num_tokens).exp().cpu().item()
    return dev_ppl


def train(model, training_dataset, validation_dataset,
          batch_size=32, lr=1e-3, max_epoch=10, log_every=10, valid_niter=100,
          model_path="model.pt"):
    model.train()

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print('Use device: %s' % device)

    model = model.to(device)

    optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    epoch = global_step = loss_sum = num_tokens = num_examples = 0
    best_valid_perplexity = float('inf')
    train_time = begin_time = time.time()
    print('Beginning maximum likelihood training')


    while True:
        train_loader = torch.utils.data.DataLoader(
            training_dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)
        epoch += 1
        batches_per_epoch = len(train_loader)
        for i, batch in enumerate(train_loader):
            global_step += 1

            # Move tensors in batch to device
            for key in batch:
                batch[key] = batch[key].to(device)

            optimizer.zero_grad()

            token_losses = compute_loss_per_token(model, batch)
            total_loss = token_losses.sum()

            loss = total_loss / batch_size
            loss.backward()

            optimizer.step()

            loss_sum += total_loss.cpu().item()
            num_tokens += token_losses.numel()
            num_examples += batch_size

            if global_step % log_every == 0:
                average_loss = loss_sum / num_examples
                average_ppl = math.exp(loss_sum / num_tokens)
                print(f"epoch {epoch} ({i}/{batches_per_epoch}) | step {global_step} | "
                      f"avg_nll={average_loss:.2f} avg_ppl={average_ppl:.2f} "
                      f"speed={num_tokens / (time.time() - train_time):.2f} words/sec "
                      f"time_elapsed={time.time() - begin_time:.2f} sec")

                train_time = time.time()
                loss_sum = num_tokens = num_examples = 0.0

            if global_step % valid_niter == 0:
                print('Begin validation ...')
                dev_perplexity = evaluate_perplexity(model, validation_dataset, batch_size=batch_size, device=device)

                print(f"validation: step {global_step} | dev_ppl={dev_perplexity}")

                if dev_perplexity < best_valid_perplexity:
                    best_valid_perplexity = dev_perplexity
                    print(f"epoch {epoch} step {global_step}: save currently the best model to '{model_path}'")
                    torch.save(model.state_dict(), model_path)
                    torch.save(optimizer.state_dict(), model_path + '.optim')
                model.train()

        if epoch == max_epoch:
            print('Reached maximum number of epochs')
            break

# %% [markdown]
# Let's train a relatively small model architecture for 15 epochs.
# With a reasonable implementation, this should take about 16 minutes on CPU / 3 minutes on GPU and we should achieve a validation perplexity of below 10!

# %%
# Set a random seed, so you obtain the same output model if you run this cell again.
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)

model = EncoderDecoderModel(
    source_vocab_size=source_tokenizer.vocab_size,
    target_vocab_size=target_tokenizer.vocab_size,
    hidden_size=32,
    intermediate_size=32 * 4,
    num_attention_heads=4,
    num_encoder_layers=3,
    num_decoder_layers=3,
    max_sequence_length=32,
    hidden_dropout_prob=0.1,
    )

print("Model architecture:", model)
print("Total number of trainable model parameters:", sum(p.numel() for p in model.parameters() if p.requires_grad))

train(model, tokenized_datasets["train"], tokenized_datasets["validation"],
      max_epoch=15, model_path="model.pt")
# Out:
# Model architecture: EncoderDecoderModel(
#   (source_embeddings): TransformerEmbeddings(
#     (token_embeddings): Embedding(3200, 32)
#     (position_embeddings): Embedding(32, 32)
#   )
#   (target_embeddings): TransformerEmbeddings(
#     (token_embeddings): Embedding(3200, 32)
#     (position_embeddings): Embedding(32, 32)
#   )
#   (encoder_blocks): ModuleList(
#     (0-2): 3 x TransformerBlock(
#       (self_attention): MultiHeadAttention(
#         (query_proj): Linear(in_features=32, out_features=32, bias=True)
#         (key_proj): Linear(in_features=32, out_features=32, bias=True)
#         (value_proj): Linear(in_features=32, out_features=32, bias=True)
#         (output_proj): Linear(in_features=32, out_features=32, bias=True)
#       )
#       (self_attention_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#       (feedforward): Sequential(
#         (0): Linear(in_features=32, out_features=128, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=128, out_features=32, bias=True)
#         (3): Dropout(p=0.1, inplace=False)
#       )
#       (feedforward_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (decoder_blocks): ModuleList(
#     (0-2): 3 x TransformerBlock(
#       (self_attention): MultiHeadAttention(
#         (query_proj): Linear(in_features=32, out_features=32, bias=True)
#         (key_proj): Linear(in_features=32, out_features=32, bias=True)
#         (value_proj): Linear(in_features=32, out_features=32, bias=True)
#         (output_proj): Linear(in_features=32, out_features=32, bias=True)
#       )
#       (self_attention_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#       (cross_attention): MultiHeadAttention(
#         (query_proj): Linear(in_features=32, out_features=32, bias=True)
#         (key_proj): Linear(in_features=32, out_features=32, bias=True)
#         (value_proj): Linear(in_features=32, out_features=32, bias=True)
#         (output_proj): Linear(in_features=32, out_features=32, bias=True)
#       )
#       (cross_attention_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#       (feedforward): Sequential(
#         (0): Linear(in_features=32, out_features=128, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=128, out_features=32, bias=True)
#         (3): Dropout(p=0.1, inplace=False)
#       )
#       (feedforward_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     )
#   )
# )
# Total number of trainable model parameters: 295936
# Use device: cpu
# Beginning maximum likelihood training
# epoch 1 (9/272) | step 10 | avg_nll=116.95 avg_ppl=9253758.21 speed=3590.64 words/sec time_elapsed=0.65 sec
# epoch 1 (19/272) | step 20 | avg_nll=83.92 avg_ppl=128967.63 speed=3329.09 words/sec time_elapsed=1.34 sec
# epoch 1 (29/272) | step 30 | avg_nll=78.91 avg_ppl=63003.62 speed=3777.39 words/sec time_elapsed=1.94 sec
# epoch 1 (39/272) | step 40 | avg_nll=73.63 avg_ppl=25526.70 speed=3950.81 words/sec time_elapsed=2.53 sec
# epoch 1 (49/272) | step 50 | avg_nll=67.90 avg_ppl=10199.78 speed=1760.35 words/sec time_elapsed=3.87 sec
# epoch 1 (59/272) | step 60 | avg_nll=62.00 avg_ppl=4429.57 speed=1133.52 words/sec time_elapsed=5.95 sec
# epoch 1 (69/272) | step 70 | avg_nll=53.84 avg_ppl=1779.56 speed=1458.12 words/sec time_elapsed=7.53 sec
# epoch 1 (79/272) | step 80 | avg_nll=51.04 avg_ppl=1144.53 speed=2223.72 words/sec time_elapsed=8.58 sec
# epoch 1 (89/272) | step 90 | avg_nll=49.17 avg_ppl=894.61 speed=2334.20 words/sec time_elapsed=9.57 sec
# epoch 1 (99/272) | step 100 | avg_nll=46.68 avg_ppl=637.94 speed=2268.44 words/sec time_elapsed=10.59 sec
# Begin validation ...
# validation: step 100 | dev_ppl=419.6422119140625
# epoch 1 step 100: save currently the best model to 'model.pt'
# epoch 1 (109/272) | step 110 | avg_nll=44.27 avg_ppl=455.74 speed=1153.11 words/sec time_elapsed=12.59 sec
# epoch 1 (119/272) | step 120 | avg_nll=43.07 avg_ppl=378.97 speed=2474.22 words/sec time_elapsed=13.54 sec
# epoch 1 (129/272) | step 130 | avg_nll=42.64 avg_ppl=335.62 speed=2665.20 words/sec time_elapsed=14.42 sec
# epoch 1 (139/272) | step 140 | avg_nll=38.81 avg_ppl=230.37 speed=1871.34 words/sec time_elapsed=15.64 sec
# epoch 1 (149/272) | step 150 | avg_nll=37.73 avg_ppl=195.28 speed=2224.01 words/sec time_elapsed=16.67 sec
# epoch 1 (159/272) | step 160 | avg_nll=36.86 avg_ppl=171.80 speed=1707.69 words/sec time_elapsed=18.01 sec
# epoch 1 (169/272) | step 170 | avg_nll=34.54 avg_ppl=132.20 speed=1368.58 words/sec time_elapsed=19.67 sec
# epoch 1 (179/272) | step 180 | avg_nll=35.61 avg_ppl=135.57 speed=1282.69 words/sec time_elapsed=21.49 sec
# epoch 1 (189/272) | step 190 | avg_nll=33.47 avg_ppl=107.17 speed=1748.84 words/sec time_elapsed=22.80 sec
# epoch 1 (199/272) | step 200 | avg_nll=33.35 avg_ppl=100.48 speed=2106.57 words/sec time_elapsed=23.90 sec
# Begin validation ...
# validation: step 200 | dev_ppl=89.45649719238281
# epoch 1 step 200: save currently the best model to 'model.pt'
# epoch 1 (209/272) | step 210 | avg_nll=34.85 avg_ppl=107.54 speed=1430.04 words/sec time_elapsed=25.56 sec
# epoch 1 (219/272) | step 220 | avg_nll=33.31 avg_ppl=99.95 speed=2006.06 words/sec time_elapsed=26.72 sec
# epoch 1 (229/272) | step 230 | avg_nll=32.91 avg_ppl=90.27 speed=1658.64 words/sec time_elapsed=28.14 sec
# epoch 1 (239/272) | step 240 | avg_nll=32.65 avg_ppl=85.39 speed=1669.03 words/sec time_elapsed=29.54 sec
# epoch 1 (249/272) | step 250 | avg_nll=32.78 avg_ppl=87.17 speed=2140.01 words/sec time_elapsed=30.64 sec
# epoch 1 (259/272) | step 260 | avg_nll=30.64 avg_ppl=69.56 speed=992.50 words/sec time_elapsed=32.97 sec
# epoch 1 (269/272) | step 270 | avg_nll=29.60 avg_ppl=60.88 speed=1051.69 words/sec time_elapsed=35.17 sec
# epoch 2 (7/272) | step 280 | avg_nll=30.64 avg_ppl=66.00 speed=1558.86 words/sec time_elapsed=36.67 sec
# epoch 2 (17/272) | step 290 | avg_nll=29.56 avg_ppl=57.34 speed=4263.72 words/sec time_elapsed=37.22 sec
# epoch 2 (27/272) | step 300 | avg_nll=28.43 avg_ppl=51.18 speed=4375.66 words/sec time_elapsed=37.75 sec
# Begin validation ...
# validation: step 300 | dev_ppl=49.063926696777344
# epoch 2 step 300: save currently the best model to 'model.pt'
# epoch 2 (37/272) | step 310 | avg_nll=28.54 avg_ppl=51.61 speed=2736.21 words/sec time_elapsed=38.60 sec
# epoch 2 (47/272) | step 320 | avg_nll=28.56 avg_ppl=53.74 speed=4329.06 words/sec time_elapsed=39.13 sec
# epoch 2 (57/272) | step 330 | avg_nll=27.06 avg_ppl=45.05 speed=4128.38 words/sec time_elapsed=39.68 sec
# epoch 2 (67/272) | step 340 | avg_nll=28.03 avg_ppl=47.55 speed=3016.30 words/sec time_elapsed=40.45 sec
# epoch 2 (77/272) | step 350 | avg_nll=28.92 avg_ppl=49.18 speed=2071.42 words/sec time_elapsed=41.60 sec
# epoch 2 (87/272) | step 360 | avg_nll=26.29 avg_ppl=38.67 speed=2125.06 words/sec time_elapsed=42.68 sec
# epoch 2 (97/272) | step 370 | avg_nll=26.36 avg_ppl=41.49 speed=1503.74 words/sec time_elapsed=44.19 sec
# epoch 2 (107/272) | step 380 | avg_nll=26.17 avg_ppl=39.50 speed=2109.77 words/sec time_elapsed=45.27 sec
# epoch 2 (117/272) | step 390 | avg_nll=27.49 avg_ppl=40.23 speed=1134.06 words/sec time_elapsed=47.37 sec
# epoch 2 (127/272) | step 400 | avg_nll=26.70 avg_ppl=39.12 speed=1236.76 words/sec time_elapsed=49.26 sec
# Begin validation ...
# validation: step 400 | dev_ppl=35.03462600708008
# epoch 2 step 400: save currently the best model to 'model.pt'
# epoch 2 (137/272) | step 410 | avg_nll=25.29 avg_ppl=33.94 speed=1064.68 words/sec time_elapsed=51.41 sec
# epoch 2 (147/272) | step 420 | avg_nll=25.42 avg_ppl=35.38 speed=1740.85 words/sec time_elapsed=52.72 sec
# epoch 2 (157/272) | step 430 | avg_nll=27.95 avg_ppl=43.97 speed=2172.72 words/sec time_elapsed=53.81 sec
# epoch 2 (167/272) | step 440 | avg_nll=25.90 avg_ppl=34.69 speed=3696.47 words/sec time_elapsed=54.44 sec
# epoch 2 (177/272) | step 450 | avg_nll=24.59 avg_ppl=30.91 speed=4117.18 words/sec time_elapsed=55.00 sec
# epoch 2 (187/272) | step 460 | avg_nll=26.13 avg_ppl=35.52 speed=4258.92 words/sec time_elapsed=55.55 sec
# epoch 2 (197/272) | step 470 | avg_nll=26.24 avg_ppl=35.34 speed=4173.38 words/sec time_elapsed=56.12 sec
# epoch 2 (207/272) | step 480 | avg_nll=25.29 avg_ppl=33.14 speed=3894.85 words/sec time_elapsed=56.71 sec
# epoch 2 (217/272) | step 490 | avg_nll=24.99 avg_ppl=31.23 speed=4202.89 words/sec time_elapsed=57.26 sec
# epoch 2 (227/272) | step 500 | avg_nll=24.67 avg_ppl=30.67 speed=4008.35 words/sec time_elapsed=57.84 sec
# Begin validation ...
# validation: step 500 | dev_ppl=28.551156997680664
# epoch 2 step 500: save currently the best model to 'model.pt'
# epoch 2 (237/272) | step 510 | avg_nll=23.65 avg_ppl=27.68 speed=2552.22 words/sec time_elapsed=58.73 sec
# epoch 2 (247/272) | step 520 | avg_nll=24.73 avg_ppl=31.98 speed=4084.57 words/sec time_elapsed=59.29 sec
# epoch 2 (257/272) | step 530 | avg_nll=24.44 avg_ppl=29.48 speed=2967.16 words/sec time_elapsed=60.07 sec
# epoch 2 (267/272) | step 540 | avg_nll=24.38 avg_ppl=27.89 speed=3023.96 words/sec time_elapsed=60.85 sec
# epoch 3 (5/272) | step 550 | avg_nll=25.13 avg_ppl=31.31 speed=2557.96 words/sec time_elapsed=61.76 sec
# epoch 3 (15/272) | step 560 | avg_nll=23.03 avg_ppl=25.85 speed=2594.92 words/sec time_elapsed=62.64 sec
# epoch 3 (25/272) | step 570 | avg_nll=23.30 avg_ppl=24.94 speed=3721.41 words/sec time_elapsed=63.26 sec
# epoch 3 (35/272) | step 580 | avg_nll=23.19 avg_ppl=25.42 speed=4042.15 words/sec time_elapsed=63.83 sec
# epoch 3 (45/272) | step 590 | avg_nll=24.10 avg_ppl=27.89 speed=4256.64 words/sec time_elapsed=64.37 sec
# epoch 3 (55/272) | step 600 | avg_nll=23.89 avg_ppl=26.03 speed=4251.19 words/sec time_elapsed=64.92 sec
# Begin validation ...
# validation: step 600 | dev_ppl=24.927377700805664
# epoch 3 step 600: save currently the best model to 'model.pt'
# epoch 3 (65/272) | step 610 | avg_nll=24.11 avg_ppl=27.26 speed=2687.24 words/sec time_elapsed=65.79 sec
# epoch 3 (75/272) | step 620 | avg_nll=23.35 avg_ppl=23.87 speed=4412.11 words/sec time_elapsed=66.33 sec
# epoch 3 (85/272) | step 630 | avg_nll=22.65 avg_ppl=23.60 speed=4202.02 words/sec time_elapsed=66.87 sec
# epoch 3 (95/272) | step 640 | avg_nll=22.93 avg_ppl=23.83 speed=4234.91 words/sec time_elapsed=67.42 sec
# epoch 3 (105/272) | step 650 | avg_nll=22.59 avg_ppl=23.59 speed=3929.83 words/sec time_elapsed=68.00 sec
# epoch 3 (115/272) | step 660 | avg_nll=23.29 avg_ppl=25.02 speed=4015.07 words/sec time_elapsed=68.58 sec
# epoch 3 (125/272) | step 670 | avg_nll=23.76 avg_ppl=25.09 speed=4584.44 words/sec time_elapsed=69.09 sec
# epoch 3 (135/272) | step 680 | avg_nll=23.00 avg_ppl=22.96 speed=4017.97 words/sec time_elapsed=69.68 sec
# epoch 3 (145/272) | step 690 | avg_nll=23.40 avg_ppl=25.03 speed=4040.91 words/sec time_elapsed=70.26 sec
# epoch 3 (155/272) | step 700 | avg_nll=22.26 avg_ppl=22.25 speed=3867.60 words/sec time_elapsed=70.85 sec
# Begin validation ...
# validation: step 700 | dev_ppl=22.110258102416992
# epoch 3 step 700: save currently the best model to 'model.pt'
# epoch 3 (165/272) | step 710 | avg_nll=23.35 avg_ppl=23.69 speed=2632.52 words/sec time_elapsed=71.75 sec
# epoch 3 (175/272) | step 720 | avg_nll=23.62 avg_ppl=25.04 speed=4287.46 words/sec time_elapsed=72.30 sec
# epoch 3 (185/272) | step 730 | avg_nll=21.78 avg_ppl=21.12 speed=3741.87 words/sec time_elapsed=72.91 sec
# epoch 3 (195/272) | step 740 | avg_nll=21.78 avg_ppl=20.86 speed=2717.03 words/sec time_elapsed=73.75 sec
# epoch 3 (205/272) | step 750 | avg_nll=21.76 avg_ppl=20.71 speed=2863.78 words/sec time_elapsed=74.55 sec
# epoch 3 (215/272) | step 760 | avg_nll=22.81 avg_ppl=22.82 speed=2753.83 words/sec time_elapsed=75.40 sec
# epoch 3 (225/272) | step 770 | avg_nll=23.13 avg_ppl=23.28 speed=2732.90 words/sec time_elapsed=76.26 sec
# epoch 3 (235/272) | step 780 | avg_nll=22.11 avg_ppl=20.34 speed=4097.75 words/sec time_elapsed=76.84 sec
# epoch 3 (245/272) | step 790 | avg_nll=21.35 avg_ppl=19.37 speed=4063.93 words/sec time_elapsed=77.41 sec
# epoch 3 (255/272) | step 800 | avg_nll=21.62 avg_ppl=20.45 speed=4074.35 words/sec time_elapsed=77.97 sec
# Begin validation ...
# validation: step 800 | dev_ppl=20.741374969482422
# epoch 3 step 800: save currently the best model to 'model.pt'
# epoch 3 (265/272) | step 810 | avg_nll=21.51 avg_ppl=20.50 speed=2609.43 words/sec time_elapsed=78.84 sec
# epoch 4 (3/272) | step 820 | avg_nll=20.51 avg_ppl=18.89 speed=3926.06 words/sec time_elapsed=79.41 sec
# epoch 4 (13/272) | step 830 | avg_nll=22.03 avg_ppl=20.52 speed=4100.19 words/sec time_elapsed=79.98 sec
# epoch 4 (23/272) | step 840 | avg_nll=22.01 avg_ppl=20.23 speed=4169.48 words/sec time_elapsed=80.54 sec
# epoch 4 (33/272) | step 850 | avg_nll=21.49 avg_ppl=19.24 speed=3966.00 words/sec time_elapsed=81.13 sec
# epoch 4 (43/272) | step 860 | avg_nll=21.63 avg_ppl=19.88 speed=3958.08 words/sec time_elapsed=81.71 sec
# epoch 4 (53/272) | step 870 | avg_nll=21.07 avg_ppl=18.53 speed=4228.49 words/sec time_elapsed=82.26 sec
# epoch 4 (63/272) | step 880 | avg_nll=21.70 avg_ppl=19.81 speed=4299.80 words/sec time_elapsed=82.80 sec
# epoch 4 (73/272) | step 890 | avg_nll=21.92 avg_ppl=19.97 speed=4004.90 words/sec time_elapsed=83.39 sec
# epoch 4 (83/272) | step 900 | avg_nll=20.83 avg_ppl=18.22 speed=4182.43 words/sec time_elapsed=83.93 sec
# Begin validation ...
# validation: step 900 | dev_ppl=18.645263671875
# epoch 4 step 900: save currently the best model to 'model.pt'
# epoch 4 (93/272) | step 910 | avg_nll=21.82 avg_ppl=19.72 speed=2721.39 words/sec time_elapsed=84.80 sec
# epoch 4 (103/272) | step 920 | avg_nll=20.75 avg_ppl=17.49 speed=4177.05 words/sec time_elapsed=85.35 sec
# epoch 4 (113/272) | step 930 | avg_nll=22.26 avg_ppl=20.75 speed=4295.42 words/sec time_elapsed=85.90 sec
# epoch 4 (123/272) | step 940 | avg_nll=21.83 avg_ppl=19.82 speed=3123.76 words/sec time_elapsed=86.65 sec
# epoch 4 (133/272) | step 950 | avg_nll=20.95 avg_ppl=18.01 speed=2972.33 words/sec time_elapsed=87.43 sec
# epoch 4 (143/272) | step 960 | avg_nll=21.31 avg_ppl=18.72 speed=2938.51 words/sec time_elapsed=88.22 sec
# epoch 4 (153/272) | step 970 | avg_nll=20.06 avg_ppl=16.31 speed=2730.50 words/sec time_elapsed=89.06 sec
# epoch 4 (163/272) | step 980 | avg_nll=21.09 avg_ppl=18.86 speed=3083.53 words/sec time_elapsed=89.81 sec
# epoch 4 (173/272) | step 990 | avg_nll=20.88 avg_ppl=17.47 speed=4023.63 words/sec time_elapsed=90.39 sec
# epoch 4 (183/272) | step 1000 | avg_nll=20.72 avg_ppl=17.52 speed=4164.77 words/sec time_elapsed=90.95 sec
# Begin validation ...
# validation: step 1000 | dev_ppl=18.06876564025879
# epoch 4 step 1000: save currently the best model to 'model.pt'
# epoch 4 (193/272) | step 1010 | avg_nll=20.48 avg_ppl=17.15 speed=2609.04 words/sec time_elapsed=91.83 sec
# epoch 4 (203/272) | step 1020 | avg_nll=20.57 avg_ppl=17.68 speed=4105.50 words/sec time_elapsed=92.39 sec
# epoch 4 (213/272) | step 1030 | avg_nll=21.07 avg_ppl=17.63 speed=4198.52 words/sec time_elapsed=92.95 sec
# epoch 4 (223/272) | step 1040 | avg_nll=20.40 avg_ppl=17.20 speed=4325.36 words/sec time_elapsed=93.48 sec
# epoch 4 (233/272) | step 1050 | avg_nll=21.66 avg_ppl=19.26 speed=4270.58 words/sec time_elapsed=94.03 sec
# epoch 4 (243/272) | step 1060 | avg_nll=20.10 avg_ppl=16.38 speed=4187.83 words/sec time_elapsed=94.58 sec
# epoch 4 (253/272) | step 1070 | avg_nll=20.66 avg_ppl=17.11 speed=3966.53 words/sec time_elapsed=95.17 sec
# epoch 4 (263/272) | step 1080 | avg_nll=20.02 avg_ppl=16.41 speed=3710.44 words/sec time_elapsed=95.78 sec
# epoch 5 (1/272) | step 1090 | avg_nll=19.43 avg_ppl=16.31 speed=4087.60 words/sec time_elapsed=96.33 sec
# epoch 5 (11/272) | step 1100 | avg_nll=19.88 avg_ppl=16.02 speed=4304.33 words/sec time_elapsed=96.86 sec
# Begin validation ...
# validation: step 1100 | dev_ppl=16.586328506469727
# epoch 5 step 1100: save currently the best model to 'model.pt'
# epoch 5 (21/272) | step 1110 | avg_nll=19.71 avg_ppl=15.44 speed=2738.13 words/sec time_elapsed=97.70 sec
# epoch 5 (31/272) | step 1120 | avg_nll=19.72 avg_ppl=15.31 speed=4276.45 words/sec time_elapsed=98.25 sec
# epoch 5 (41/272) | step 1130 | avg_nll=19.58 avg_ppl=15.28 speed=4184.26 words/sec time_elapsed=98.79 sec
# epoch 5 (51/272) | step 1140 | avg_nll=20.53 avg_ppl=17.11 speed=3808.53 words/sec time_elapsed=99.40 sec
# epoch 5 (61/272) | step 1150 | avg_nll=20.98 avg_ppl=17.11 speed=3210.25 words/sec time_elapsed=100.14 sec
# epoch 5 (71/272) | step 1160 | avg_nll=20.29 avg_ppl=16.40 speed=2931.03 words/sec time_elapsed=100.93 sec
# epoch 5 (81/272) | step 1170 | avg_nll=19.87 avg_ppl=15.31 speed=2778.60 words/sec time_elapsed=101.77 sec
# epoch 5 (91/272) | step 1180 | avg_nll=20.06 avg_ppl=16.29 speed=2783.52 words/sec time_elapsed=102.60 sec
# epoch 5 (101/272) | step 1190 | avg_nll=20.55 avg_ppl=16.54 speed=4224.15 words/sec time_elapsed=103.15 sec
# epoch 5 (111/272) | step 1200 | avg_nll=20.79 avg_ppl=16.30 speed=4181.81 words/sec time_elapsed=103.72 sec
# Begin validation ...
# validation: step 1200 | dev_ppl=15.990256309509277
# epoch 5 step 1200: save currently the best model to 'model.pt'
# epoch 5 (121/272) | step 1210 | avg_nll=19.02 avg_ppl=14.80 speed=2731.95 words/sec time_elapsed=104.55 sec
# epoch 5 (131/272) | step 1220 | avg_nll=19.55 avg_ppl=15.19 speed=4054.12 words/sec time_elapsed=105.12 sec
# epoch 5 (141/272) | step 1230 | avg_nll=19.51 avg_ppl=15.10 speed=4169.11 words/sec time_elapsed=105.67 sec
# epoch 5 (151/272) | step 1240 | avg_nll=19.47 avg_ppl=14.69 speed=4068.85 words/sec time_elapsed=106.24 sec
# epoch 5 (161/272) | step 1250 | avg_nll=20.05 avg_ppl=16.22 speed=4180.82 words/sec time_elapsed=106.79 sec
# epoch 5 (171/272) | step 1260 | avg_nll=19.75 avg_ppl=15.09 speed=3986.22 words/sec time_elapsed=107.38 sec
# epoch 5 (181/272) | step 1270 | avg_nll=20.21 avg_ppl=15.81 speed=3973.80 words/sec time_elapsed=107.97 sec
# epoch 5 (191/272) | step 1280 | avg_nll=19.88 avg_ppl=15.45 speed=4281.09 words/sec time_elapsed=108.51 sec
# epoch 5 (201/272) | step 1290 | avg_nll=20.98 avg_ppl=17.04 speed=4060.37 words/sec time_elapsed=109.09 sec
# epoch 5 (211/272) | step 1300 | avg_nll=19.62 avg_ppl=14.72 speed=4431.19 words/sec time_elapsed=109.62 sec
# Begin validation ...
# validation: step 1300 | dev_ppl=15.159873008728027
# epoch 5 step 1300: save currently the best model to 'model.pt'
# epoch 5 (221/272) | step 1310 | avg_nll=19.22 avg_ppl=14.30 speed=2676.86 words/sec time_elapsed=110.49 sec
# epoch 5 (231/272) | step 1320 | avg_nll=19.48 avg_ppl=14.92 speed=3880.44 words/sec time_elapsed=111.08 sec
# epoch 5 (241/272) | step 1330 | avg_nll=18.36 avg_ppl=12.95 speed=4176.98 words/sec time_elapsed=111.63 sec
# epoch 5 (251/272) | step 1340 | avg_nll=18.76 avg_ppl=13.79 speed=3979.81 words/sec time_elapsed=112.21 sec
# epoch 5 (261/272) | step 1350 | avg_nll=19.46 avg_ppl=14.97 speed=3688.73 words/sec time_elapsed=112.83 sec
# epoch 5 (271/272) | step 1360 | avg_nll=19.80 avg_ppl=15.35 speed=2742.45 words/sec time_elapsed=113.68 sec
# epoch 6 (9/272) | step 1370 | avg_nll=19.13 avg_ppl=14.03 speed=2708.72 words/sec time_elapsed=114.53 sec
# epoch 6 (19/272) | step 1380 | avg_nll=18.21 avg_ppl=12.54 speed=2907.05 words/sec time_elapsed=115.32 sec
# epoch 6 (29/272) | step 1390 | avg_nll=19.16 avg_ppl=13.79 speed=3561.11 words/sec time_elapsed=115.98 sec
# epoch 6 (39/272) | step 1400 | avg_nll=18.67 avg_ppl=13.18 speed=4215.73 words/sec time_elapsed=116.53 sec
# Begin validation ...
# validation: step 1400 | dev_ppl=14.79204273223877
# epoch 6 step 1400: save currently the best model to 'model.pt'
# epoch 6 (49/272) | step 1410 | avg_nll=19.11 avg_ppl=14.03 speed=2659.92 words/sec time_elapsed=117.40 sec
# epoch 6 (59/272) | step 1420 | avg_nll=19.23 avg_ppl=14.41 speed=3116.22 words/sec time_elapsed=118.14 sec
# epoch 6 (69/272) | step 1430 | avg_nll=19.71 avg_ppl=14.98 speed=2845.25 words/sec time_elapsed=118.96 sec
# epoch 6 (79/272) | step 1440 | avg_nll=18.12 avg_ppl=12.41 speed=1800.18 words/sec time_elapsed=120.24 sec
# epoch 6 (89/272) | step 1450 | avg_nll=19.13 avg_ppl=14.30 speed=2037.49 words/sec time_elapsed=121.37 sec
# epoch 6 (99/272) | step 1460 | avg_nll=18.64 avg_ppl=13.20 speed=1711.89 words/sec time_elapsed=122.73 sec
# epoch 6 (109/272) | step 1470 | avg_nll=19.81 avg_ppl=14.93 speed=2386.90 words/sec time_elapsed=123.72 sec
# epoch 6 (119/272) | step 1480 | avg_nll=18.89 avg_ppl=13.75 speed=2408.15 words/sec time_elapsed=124.68 sec
# epoch 6 (129/272) | step 1490 | avg_nll=18.89 avg_ppl=13.59 speed=2622.78 words/sec time_elapsed=125.56 sec
# epoch 6 (139/272) | step 1500 | avg_nll=19.31 avg_ppl=13.94 speed=1659.40 words/sec time_elapsed=126.98 sec
# Begin validation ...
# validation: step 1500 | dev_ppl=14.202213287353516
# epoch 6 step 1500: save currently the best model to 'model.pt'
# epoch 6 (149/272) | step 1510 | avg_nll=18.89 avg_ppl=13.92 speed=907.35 words/sec time_elapsed=129.50 sec
# epoch 6 (159/272) | step 1520 | avg_nll=18.71 avg_ppl=12.46 speed=2575.78 words/sec time_elapsed=130.43 sec
# epoch 6 (169/272) | step 1530 | avg_nll=18.96 avg_ppl=13.63 speed=2711.43 words/sec time_elapsed=131.29 sec
# epoch 6 (179/272) | step 1540 | avg_nll=18.29 avg_ppl=13.18 speed=2344.97 words/sec time_elapsed=132.26 sec
# epoch 6 (189/272) | step 1550 | avg_nll=17.94 avg_ppl=12.23 speed=2157.87 words/sec time_elapsed=133.32 sec
# epoch 6 (199/272) | step 1560 | avg_nll=17.74 avg_ppl=11.70 speed=2245.60 words/sec time_elapsed=134.35 sec
# epoch 6 (209/272) | step 1570 | avg_nll=18.42 avg_ppl=12.89 speed=4033.13 words/sec time_elapsed=134.92 sec
# epoch 6 (219/272) | step 1580 | avg_nll=19.34 avg_ppl=14.14 speed=4179.34 words/sec time_elapsed=135.48 sec
# epoch 6 (229/272) | step 1590 | avg_nll=18.40 avg_ppl=12.81 speed=4019.05 words/sec time_elapsed=136.06 sec
# epoch 6 (239/272) | step 1600 | avg_nll=18.92 avg_ppl=13.26 speed=3929.31 words/sec time_elapsed=136.65 sec
# Begin validation ...
# validation: step 1600 | dev_ppl=13.70938491821289
# epoch 6 step 1600: save currently the best model to 'model.pt'
# epoch 6 (249/272) | step 1610 | avg_nll=18.78 avg_ppl=13.13 speed=2752.06 words/sec time_elapsed=137.50 sec
# epoch 6 (259/272) | step 1620 | avg_nll=19.27 avg_ppl=13.94 speed=4132.83 words/sec time_elapsed=138.07 sec
# epoch 6 (269/272) | step 1630 | avg_nll=18.14 avg_ppl=12.54 speed=4140.37 words/sec time_elapsed=138.62 sec
# epoch 7 (7/272) | step 1640 | avg_nll=18.72 avg_ppl=12.52 speed=3956.09 words/sec time_elapsed=139.22 sec
# epoch 7 (17/272) | step 1650 | avg_nll=18.12 avg_ppl=12.23 speed=3254.76 words/sec time_elapsed=139.94 sec
# epoch 7 (27/272) | step 1660 | avg_nll=18.09 avg_ppl=12.80 speed=3039.31 words/sec time_elapsed=140.68 sec
# epoch 7 (37/272) | step 1670 | avg_nll=17.67 avg_ppl=11.95 speed=2811.74 words/sec time_elapsed=141.49 sec
# epoch 7 (47/272) | step 1680 | avg_nll=17.87 avg_ppl=11.53 speed=1398.26 words/sec time_elapsed=143.17 sec
# epoch 7 (57/272) | step 1690 | avg_nll=17.34 avg_ppl=11.22 speed=1443.92 words/sec time_elapsed=144.76 sec
# epoch 7 (67/272) | step 1700 | avg_nll=17.88 avg_ppl=11.90 speed=2000.50 words/sec time_elapsed=145.92 sec
# Begin validation ...
# validation: step 1700 | dev_ppl=13.199437141418457
# epoch 7 step 1700: save currently the best model to 'model.pt'
# epoch 7 (77/272) | step 1710 | avg_nll=17.44 avg_ppl=11.67 speed=1717.39 words/sec time_elapsed=147.24 sec
# epoch 7 (87/272) | step 1720 | avg_nll=17.58 avg_ppl=11.41 speed=2798.66 words/sec time_elapsed=148.07 sec
# epoch 7 (97/272) | step 1730 | avg_nll=18.89 avg_ppl=13.08 speed=2491.60 words/sec time_elapsed=149.02 sec
# epoch 7 (107/272) | step 1740 | avg_nll=18.31 avg_ppl=12.34 speed=2685.05 words/sec time_elapsed=149.89 sec
# epoch 7 (117/272) | step 1750 | avg_nll=19.02 avg_ppl=12.87 speed=2802.51 words/sec time_elapsed=150.74 sec
# epoch 7 (127/272) | step 1760 | avg_nll=16.33 avg_ppl=10.23 speed=2576.90 words/sec time_elapsed=151.61 sec
# epoch 7 (137/272) | step 1770 | avg_nll=18.04 avg_ppl=11.90 speed=3679.52 words/sec time_elapsed=152.24 sec
# epoch 7 (147/272) | step 1780 | avg_nll=18.14 avg_ppl=12.31 speed=3849.78 words/sec time_elapsed=152.84 sec
# epoch 7 (157/272) | step 1790 | avg_nll=17.38 avg_ppl=11.39 speed=3516.39 words/sec time_elapsed=153.49 sec
# epoch 7 (167/272) | step 1800 | avg_nll=18.72 avg_ppl=12.88 speed=2969.70 words/sec time_elapsed=154.28 sec
# Begin validation ...
# validation: step 1800 | dev_ppl=12.724260330200195
# epoch 7 step 1800: save currently the best model to 'model.pt'
# epoch 7 (177/272) | step 1810 | avg_nll=19.46 avg_ppl=13.88 speed=1843.05 words/sec time_elapsed=155.57 sec
# epoch 7 (187/272) | step 1820 | avg_nll=17.57 avg_ppl=11.46 speed=2710.63 words/sec time_elapsed=156.42 sec
# epoch 7 (197/272) | step 1830 | avg_nll=16.87 avg_ppl=10.74 speed=4088.09 words/sec time_elapsed=156.98 sec
# epoch 7 (207/272) | step 1840 | avg_nll=17.97 avg_ppl=11.90 speed=4122.17 words/sec time_elapsed=157.54 sec
# epoch 7 (217/272) | step 1850 | avg_nll=18.01 avg_ppl=12.00 speed=4322.05 words/sec time_elapsed=158.08 sec
# epoch 7 (227/272) | step 1860 | avg_nll=17.90 avg_ppl=11.85 speed=4304.83 words/sec time_elapsed=158.62 sec
# epoch 7 (237/272) | step 1870 | avg_nll=17.79 avg_ppl=11.14 speed=3697.87 words/sec time_elapsed=159.26 sec
# epoch 7 (247/272) | step 1880 | avg_nll=17.31 avg_ppl=11.42 speed=3732.09 words/sec time_elapsed=159.87 sec
# epoch 7 (257/272) | step 1890 | avg_nll=17.73 avg_ppl=11.05 speed=4134.90 words/sec time_elapsed=160.44 sec
# epoch 7 (267/272) | step 1900 | avg_nll=17.36 avg_ppl=11.28 speed=4022.57 words/sec time_elapsed=161.01 sec
# Begin validation ...
# validation: step 1900 | dev_ppl=12.606302261352539
# epoch 7 step 1900: save currently the best model to 'model.pt'
# epoch 8 (5/272) | step 1910 | avg_nll=18.29 avg_ppl=12.27 speed=2678.05 words/sec time_elapsed=161.88 sec
# epoch 8 (15/272) | step 1920 | avg_nll=16.11 avg_ppl=9.75 speed=4151.26 words/sec time_elapsed=162.43 sec
# epoch 8 (25/272) | step 1930 | avg_nll=16.91 avg_ppl=10.37 speed=4009.62 words/sec time_elapsed=163.00 sec
# epoch 8 (35/272) | step 1940 | avg_nll=17.70 avg_ppl=11.49 speed=2885.63 words/sec time_elapsed=163.81 sec
# epoch 8 (45/272) | step 1950 | avg_nll=17.66 avg_ppl=11.16 speed=3030.05 words/sec time_elapsed=164.58 sec
# epoch 8 (55/272) | step 1960 | avg_nll=17.37 avg_ppl=10.88 speed=2773.68 words/sec time_elapsed=165.42 sec
# epoch 8 (65/272) | step 1970 | avg_nll=16.81 avg_ppl=10.45 speed=3073.79 words/sec time_elapsed=166.17 sec
# epoch 8 (75/272) | step 1980 | avg_nll=17.72 avg_ppl=11.26 speed=3051.44 words/sec time_elapsed=166.94 sec
# epoch 8 (85/272) | step 1990 | avg_nll=16.76 avg_ppl=10.45 speed=2984.06 words/sec time_elapsed=167.70 sec
# epoch 8 (95/272) | step 2000 | avg_nll=16.55 avg_ppl=9.88 speed=2699.63 words/sec time_elapsed=168.56 sec
# Begin validation ...
# validation: step 2000 | dev_ppl=12.32253646850586
# epoch 8 step 2000: save currently the best model to 'model.pt'
# epoch 8 (105/272) | step 2010 | avg_nll=17.10 avg_ppl=11.09 speed=1264.51 words/sec time_elapsed=170.36 sec
# epoch 8 (115/272) | step 2020 | avg_nll=16.59 avg_ppl=10.18 speed=2113.53 words/sec time_elapsed=171.44 sec
# epoch 8 (125/272) | step 2030 | avg_nll=17.06 avg_ppl=10.69 speed=3883.62 words/sec time_elapsed=172.04 sec
# epoch 8 (135/272) | step 2040 | avg_nll=17.45 avg_ppl=11.54 speed=3491.83 words/sec time_elapsed=172.69 sec
# epoch 8 (145/272) | step 2050 | avg_nll=17.95 avg_ppl=11.31 speed=4401.90 words/sec time_elapsed=173.23 sec
# epoch 8 (155/272) | step 2060 | avg_nll=16.80 avg_ppl=10.16 speed=4128.26 words/sec time_elapsed=173.79 sec
# epoch 8 (165/272) | step 2070 | avg_nll=17.24 avg_ppl=10.56 speed=3992.59 words/sec time_elapsed=174.38 sec
# epoch 8 (175/272) | step 2080 | avg_nll=17.78 avg_ppl=11.55 speed=4119.18 words/sec time_elapsed=174.94 sec
# epoch 8 (185/272) | step 2090 | avg_nll=18.36 avg_ppl=12.04 speed=4222.58 words/sec time_elapsed=175.50 sec
# epoch 8 (195/272) | step 2100 | avg_nll=17.42 avg_ppl=10.90 speed=4267.20 words/sec time_elapsed=176.05 sec
# Begin validation ...
# validation: step 2100 | dev_ppl=12.068024635314941
# epoch 8 step 2100: save currently the best model to 'model.pt'
# epoch 8 (205/272) | step 2110 | avg_nll=17.44 avg_ppl=11.13 speed=2730.87 words/sec time_elapsed=176.90 sec
# epoch 8 (215/272) | step 2120 | avg_nll=17.83 avg_ppl=10.91 speed=4091.34 words/sec time_elapsed=177.48 sec
# epoch 8 (225/272) | step 2130 | avg_nll=18.10 avg_ppl=11.60 speed=4222.69 words/sec time_elapsed=178.04 sec
# epoch 8 (235/272) | step 2140 | avg_nll=15.79 avg_ppl=9.01 speed=4008.18 words/sec time_elapsed=178.62 sec
# epoch 8 (245/272) | step 2150 | avg_nll=16.21 avg_ppl=9.87 speed=4107.51 words/sec time_elapsed=179.17 sec
# epoch 8 (255/272) | step 2160 | avg_nll=16.76 avg_ppl=10.04 speed=3154.04 words/sec time_elapsed=179.91 sec
# epoch 8 (265/272) | step 2170 | avg_nll=16.53 avg_ppl=10.02 speed=2821.23 words/sec time_elapsed=180.72 sec
# epoch 9 (3/272) | step 2180 | avg_nll=15.87 avg_ppl=9.81 speed=2723.57 words/sec time_elapsed=181.54 sec
# epoch 9 (13/272) | step 2190 | avg_nll=16.11 avg_ppl=9.44 speed=2753.08 words/sec time_elapsed=182.37 sec
# epoch 9 (23/272) | step 2200 | avg_nll=15.59 avg_ppl=8.93 speed=3123.26 words/sec time_elapsed=183.10 sec
# Begin validation ...
# validation: step 2200 | dev_ppl=11.88739013671875
# epoch 9 step 2200: save currently the best model to 'model.pt'
# epoch 9 (33/272) | step 2210 | avg_nll=16.46 avg_ppl=9.58 speed=2643.96 words/sec time_elapsed=183.99 sec
# epoch 9 (43/272) | step 2220 | avg_nll=16.28 avg_ppl=9.73 speed=4003.02 words/sec time_elapsed=184.56 sec
# epoch 9 (53/272) | step 2230 | avg_nll=16.30 avg_ppl=9.57 speed=4024.83 words/sec time_elapsed=185.13 sec
# epoch 9 (63/272) | step 2240 | avg_nll=17.18 avg_ppl=10.46 speed=4022.07 words/sec time_elapsed=185.72 sec
# epoch 9 (73/272) | step 2250 | avg_nll=16.90 avg_ppl=10.05 speed=4069.29 words/sec time_elapsed=186.29 sec
# epoch 9 (83/272) | step 2260 | avg_nll=16.36 avg_ppl=9.47 speed=3802.74 words/sec time_elapsed=186.90 sec
# epoch 9 (93/272) | step 2270 | avg_nll=16.87 avg_ppl=10.13 speed=4156.72 words/sec time_elapsed=187.47 sec
# epoch 9 (103/272) | step 2280 | avg_nll=16.39 avg_ppl=9.71 speed=3931.15 words/sec time_elapsed=188.05 sec
# epoch 9 (113/272) | step 2290 | avg_nll=16.79 avg_ppl=9.98 speed=4173.02 words/sec time_elapsed=188.61 sec
# epoch 9 (123/272) | step 2300 | avg_nll=16.40 avg_ppl=9.59 speed=4232.73 words/sec time_elapsed=189.16 sec
# Begin validation ...
# validation: step 2300 | dev_ppl=11.370116233825684
# epoch 9 step 2300: save currently the best model to 'model.pt'
# epoch 9 (133/272) | step 2310 | avg_nll=17.49 avg_ppl=10.87 speed=2619.20 words/sec time_elapsed=190.06 sec
# epoch 9 (143/272) | step 2320 | avg_nll=17.08 avg_ppl=10.36 speed=4093.81 words/sec time_elapsed=190.63 sec
# epoch 9 (153/272) | step 2330 | avg_nll=16.60 avg_ppl=10.33 speed=4018.38 words/sec time_elapsed=191.19 sec
# epoch 9 (163/272) | step 2340 | avg_nll=16.26 avg_ppl=9.44 speed=3909.27 words/sec time_elapsed=191.79 sec
# epoch 9 (173/272) | step 2350 | avg_nll=16.45 avg_ppl=9.86 speed=3915.31 words/sec time_elapsed=192.38 sec
# epoch 9 (183/272) | step 2360 | avg_nll=17.05 avg_ppl=10.12 speed=3667.56 words/sec time_elapsed=193.02 sec
# epoch 9 (193/272) | step 2370 | avg_nll=16.01 avg_ppl=9.34 speed=2847.52 words/sec time_elapsed=193.82 sec
# epoch 9 (203/272) | step 2380 | avg_nll=17.07 avg_ppl=10.36 speed=2921.94 words/sec time_elapsed=194.62 sec
# epoch 9 (213/272) | step 2390 | avg_nll=16.55 avg_ppl=9.86 speed=2319.08 words/sec time_elapsed=195.62 sec
# epoch 9 (223/272) | step 2400 | avg_nll=15.38 avg_ppl=8.73 speed=2775.02 words/sec time_elapsed=196.44 sec
# Begin validation ...
# validation: step 2400 | dev_ppl=11.081021308898926
# epoch 9 step 2400: save currently the best model to 'model.pt'
# epoch 9 (233/272) | step 2410 | avg_nll=16.63 avg_ppl=9.79 speed=2593.28 words/sec time_elapsed=197.34 sec
# epoch 9 (243/272) | step 2420 | avg_nll=16.45 avg_ppl=9.35 speed=4180.21 words/sec time_elapsed=197.91 sec
# epoch 9 (253/272) | step 2430 | avg_nll=15.95 avg_ppl=8.81 speed=3963.63 words/sec time_elapsed=198.50 sec
# epoch 9 (263/272) | step 2440 | avg_nll=15.46 avg_ppl=8.60 speed=4098.49 words/sec time_elapsed=199.06 sec
# epoch 10 (1/272) | step 2450 | avg_nll=15.93 avg_ppl=9.20 speed=3980.61 words/sec time_elapsed=199.64 sec
# epoch 10 (11/272) | step 2460 | avg_nll=16.68 avg_ppl=9.79 speed=4008.69 words/sec time_elapsed=200.22 sec
# epoch 10 (21/272) | step 2470 | avg_nll=16.66 avg_ppl=9.60 speed=4292.93 words/sec time_elapsed=200.77 sec
# epoch 10 (31/272) | step 2480 | avg_nll=16.47 avg_ppl=9.39 speed=4146.30 words/sec time_elapsed=201.34 sec
# epoch 10 (41/272) | step 2490 | avg_nll=14.91 avg_ppl=8.17 speed=4286.71 words/sec time_elapsed=201.87 sec
# epoch 10 (51/272) | step 2500 | avg_nll=15.55 avg_ppl=8.79 speed=4064.49 words/sec time_elapsed=202.43 sec
# Begin validation ...
# validation: step 2500 | dev_ppl=11.05341911315918
# epoch 10 step 2500: save currently the best model to 'model.pt'
# epoch 10 (61/272) | step 2510 | avg_nll=15.75 avg_ppl=8.70 speed=2704.64 words/sec time_elapsed=203.30 sec
# epoch 10 (71/272) | step 2520 | avg_nll=16.88 avg_ppl=9.97 speed=4092.69 words/sec time_elapsed=203.87 sec
# epoch 10 (81/272) | step 2530 | avg_nll=16.51 avg_ppl=9.30 speed=3887.54 words/sec time_elapsed=204.48 sec
# epoch 10 (91/272) | step 2540 | avg_nll=15.84 avg_ppl=8.77 speed=4230.65 words/sec time_elapsed=205.03 sec
# epoch 10 (101/272) | step 2550 | avg_nll=15.43 avg_ppl=8.79 speed=3870.22 words/sec time_elapsed=205.62 sec
# epoch 10 (111/272) | step 2560 | avg_nll=16.39 avg_ppl=9.45 speed=4313.39 words/sec time_elapsed=206.16 sec
# epoch 10 (121/272) | step 2570 | avg_nll=15.66 avg_ppl=8.88 speed=2941.89 words/sec time_elapsed=206.94 sec
# epoch 10 (131/272) | step 2580 | avg_nll=15.80 avg_ppl=8.91 speed=2976.11 words/sec time_elapsed=207.72 sec
# epoch 10 (141/272) | step 2590 | avg_nll=14.86 avg_ppl=7.99 speed=2713.23 words/sec time_elapsed=208.56 sec
# epoch 10 (151/272) | step 2600 | avg_nll=15.29 avg_ppl=8.35 speed=2639.30 words/sec time_elapsed=209.44 sec
# Begin validation ...
# validation: step 2600 | dev_ppl=10.782767295837402
# epoch 10 step 2600: save currently the best model to 'model.pt'
# epoch 10 (161/272) | step 2610 | avg_nll=14.62 avg_ppl=7.72 speed=2473.56 words/sec time_elapsed=210.36 sec
# epoch 10 (171/272) | step 2620 | avg_nll=15.47 avg_ppl=8.74 speed=4162.91 words/sec time_elapsed=210.91 sec
# epoch 10 (181/272) | step 2630 | avg_nll=15.27 avg_ppl=8.26 speed=4026.20 words/sec time_elapsed=211.49 sec
# epoch 10 (191/272) | step 2640 | avg_nll=16.70 avg_ppl=9.86 speed=3834.19 words/sec time_elapsed=212.09 sec
# epoch 10 (201/272) | step 2650 | avg_nll=15.72 avg_ppl=8.59 speed=4058.05 words/sec time_elapsed=212.67 sec
# epoch 10 (211/272) | step 2660 | avg_nll=15.39 avg_ppl=8.37 speed=3920.62 words/sec time_elapsed=213.26 sec
# epoch 10 (221/272) | step 2670 | avg_nll=15.44 avg_ppl=8.65 speed=4119.37 words/sec time_elapsed=213.82 sec
# epoch 10 (231/272) | step 2680 | avg_nll=16.19 avg_ppl=9.05 speed=3711.89 words/sec time_elapsed=214.45 sec
# epoch 10 (241/272) | step 2690 | avg_nll=15.85 avg_ppl=8.85 speed=3949.43 words/sec time_elapsed=215.04 sec
# epoch 10 (251/272) | step 2700 | avg_nll=14.93 avg_ppl=8.08 speed=4122.96 words/sec time_elapsed=215.60 sec
# Begin validation ...
# validation: step 2700 | dev_ppl=10.354736328125
# epoch 10 step 2700: save currently the best model to 'model.pt'
# epoch 10 (261/272) | step 2710 | avg_nll=15.72 avg_ppl=8.76 speed=2647.65 words/sec time_elapsed=216.47 sec
# epoch 10 (271/272) | step 2720 | avg_nll=15.79 avg_ppl=8.88 speed=4093.37 words/sec time_elapsed=217.04 sec
# epoch 11 (9/272) | step 2730 | avg_nll=15.05 avg_ppl=8.13 speed=4028.31 words/sec time_elapsed=217.61 sec
# epoch 11 (19/272) | step 2740 | avg_nll=14.34 avg_ppl=7.26 speed=4018.61 words/sec time_elapsed=218.19 sec
# epoch 11 (29/272) | step 2750 | avg_nll=15.64 avg_ppl=8.30 speed=4167.79 words/sec time_elapsed=218.75 sec
# epoch 11 (39/272) | step 2760 | avg_nll=15.33 avg_ppl=8.13 speed=4080.86 words/sec time_elapsed=219.33 sec
# epoch 11 (49/272) | step 2770 | avg_nll=16.13 avg_ppl=9.03 speed=3170.85 words/sec time_elapsed=220.07 sec
# epoch 11 (59/272) | step 2780 | avg_nll=15.29 avg_ppl=8.12 speed=2918.74 words/sec time_elapsed=220.87 sec
# epoch 11 (69/272) | step 2790 | avg_nll=14.88 avg_ppl=8.01 speed=2697.90 words/sec time_elapsed=221.72 sec
# epoch 11 (79/272) | step 2800 | avg_nll=14.54 avg_ppl=7.48 speed=2640.25 words/sec time_elapsed=222.60 sec
# Begin validation ...
# validation: step 2800 | dev_ppl=10.65262222290039
# epoch 11 (89/272) | step 2810 | avg_nll=14.82 avg_ppl=7.74 speed=2586.40 words/sec time_elapsed=223.49 sec
# epoch 11 (99/272) | step 2820 | avg_nll=15.83 avg_ppl=8.94 speed=3921.76 words/sec time_elapsed=224.08 sec
# epoch 11 (109/272) | step 2830 | avg_nll=14.31 avg_ppl=7.08 speed=4157.54 words/sec time_elapsed=224.65 sec
# epoch 11 (119/272) | step 2840 | avg_nll=15.21 avg_ppl=8.45 speed=2086.13 words/sec time_elapsed=225.74 sec
# epoch 11 (129/272) | step 2850 | avg_nll=16.17 avg_ppl=9.20 speed=4001.88 words/sec time_elapsed=226.32 sec
# epoch 11 (139/272) | step 2860 | avg_nll=15.89 avg_ppl=8.79 speed=4101.95 words/sec time_elapsed=226.89 sec
# epoch 11 (149/272) | step 2870 | avg_nll=14.71 avg_ppl=7.51 speed=4089.08 words/sec time_elapsed=227.46 sec
# epoch 11 (159/272) | step 2880 | avg_nll=15.57 avg_ppl=8.49 speed=3879.26 words/sec time_elapsed=228.06 sec
# epoch 11 (169/272) | step 2890 | avg_nll=15.43 avg_ppl=8.25 speed=4302.10 words/sec time_elapsed=228.61 sec
# epoch 11 (179/272) | step 2900 | avg_nll=15.44 avg_ppl=8.37 speed=4033.61 words/sec time_elapsed=229.19 sec
# Begin validation ...
# validation: step 2900 | dev_ppl=10.3283052444458
# epoch 11 step 2900: save currently the best model to 'model.pt'
# epoch 11 (189/272) | step 2910 | avg_nll=15.46 avg_ppl=8.41 speed=2639.33 words/sec time_elapsed=230.07 sec
# epoch 11 (199/272) | step 2920 | avg_nll=14.80 avg_ppl=7.88 speed=4112.79 words/sec time_elapsed=230.62 sec
# epoch 11 (209/272) | step 2930 | avg_nll=14.78 avg_ppl=7.99 speed=3760.06 words/sec time_elapsed=231.23 sec
# epoch 11 (219/272) | step 2940 | avg_nll=15.57 avg_ppl=8.46 speed=3505.23 words/sec time_elapsed=231.89 sec
# epoch 11 (229/272) | step 2950 | avg_nll=14.24 avg_ppl=7.29 speed=3511.71 words/sec time_elapsed=232.55 sec
# epoch 11 (239/272) | step 2960 | avg_nll=14.44 avg_ppl=7.42 speed=3050.63 words/sec time_elapsed=233.30 sec
# epoch 11 (249/272) | step 2970 | avg_nll=14.78 avg_ppl=7.69 speed=2891.29 words/sec time_elapsed=234.11 sec
# epoch 11 (259/272) | step 2980 | avg_nll=14.86 avg_ppl=7.90 speed=2801.11 words/sec time_elapsed=234.93 sec
# epoch 11 (269/272) | step 2990 | avg_nll=14.28 avg_ppl=7.37 speed=2682.69 words/sec time_elapsed=235.78 sec
# epoch 12 (7/272) | step 3000 | avg_nll=13.48 avg_ppl=6.66 speed=4065.51 words/sec time_elapsed=236.34 sec
# Begin validation ...
# validation: step 3000 | dev_ppl=10.174821853637695
# epoch 12 step 3000: save currently the best model to 'model.pt'
# epoch 12 (17/272) | step 3010 | avg_nll=15.03 avg_ppl=7.74 speed=2641.96 words/sec time_elapsed=237.23 sec
# epoch 12 (27/272) | step 3020 | avg_nll=14.58 avg_ppl=7.49 speed=3839.17 words/sec time_elapsed=237.84 sec
# epoch 12 (37/272) | step 3030 | avg_nll=13.43 avg_ppl=6.47 speed=4270.35 words/sec time_elapsed=238.38 sec
# epoch 12 (47/272) | step 3040 | avg_nll=15.28 avg_ppl=8.21 speed=4058.24 words/sec time_elapsed=238.95 sec
# epoch 12 (57/272) | step 3050 | avg_nll=14.69 avg_ppl=7.56 speed=4379.33 words/sec time_elapsed=239.48 sec
# epoch 12 (67/272) | step 3060 | avg_nll=15.13 avg_ppl=7.84 speed=3926.78 words/sec time_elapsed=240.08 sec
# epoch 12 (77/272) | step 3070 | avg_nll=14.22 avg_ppl=7.22 speed=3951.56 words/sec time_elapsed=240.66 sec
# epoch 12 (87/272) | step 3080 | avg_nll=15.71 avg_ppl=8.53 speed=4148.27 words/sec time_elapsed=241.23 sec
# epoch 12 (97/272) | step 3090 | avg_nll=14.55 avg_ppl=7.55 speed=4050.36 words/sec time_elapsed=241.80 sec
# epoch 12 (107/272) | step 3100 | avg_nll=14.70 avg_ppl=7.86 speed=4291.38 words/sec time_elapsed=242.33 sec
# Begin validation ...
# validation: step 3100 | dev_ppl=9.907769203186035
# epoch 12 step 3100: save currently the best model to 'model.pt'
# epoch 12 (117/272) | step 3110 | avg_nll=13.39 avg_ppl=6.46 speed=2572.11 words/sec time_elapsed=243.22 sec
# epoch 12 (127/272) | step 3120 | avg_nll=14.25 avg_ppl=7.07 speed=3894.50 words/sec time_elapsed=243.82 sec
# epoch 12 (137/272) | step 3130 | avg_nll=13.88 avg_ppl=6.91 speed=4193.93 words/sec time_elapsed=244.37 sec
# epoch 12 (147/272) | step 3140 | avg_nll=13.73 avg_ppl=6.80 speed=3973.98 words/sec time_elapsed=244.95 sec
# epoch 12 (157/272) | step 3150 | avg_nll=15.38 avg_ppl=7.84 speed=3757.52 words/sec time_elapsed=245.58 sec
# epoch 12 (167/272) | step 3160 | avg_nll=13.54 avg_ppl=6.60 speed=3097.98 words/sec time_elapsed=246.32 sec
# epoch 12 (177/272) | step 3170 | avg_nll=13.76 avg_ppl=6.86 speed=1208.25 words/sec time_elapsed=248.22 sec
# epoch 12 (187/272) | step 3180 | avg_nll=14.51 avg_ppl=7.25 speed=1294.22 words/sec time_elapsed=250.03 sec
# epoch 12 (197/272) | step 3190 | avg_nll=14.00 avg_ppl=6.96 speed=2582.94 words/sec time_elapsed=250.92 sec
# epoch 12 (207/272) | step 3200 | avg_nll=14.86 avg_ppl=7.89 speed=2877.89 words/sec time_elapsed=251.72 sec
# Begin validation ...
# validation: step 3200 | dev_ppl=9.674352645874023
# epoch 12 step 3200: save currently the best model to 'model.pt'
# epoch 12 (217/272) | step 3210 | avg_nll=15.18 avg_ppl=8.08 speed=1519.20 words/sec time_elapsed=253.26 sec
# epoch 12 (227/272) | step 3220 | avg_nll=15.16 avg_ppl=7.91 speed=2829.99 words/sec time_elapsed=254.09 sec
# epoch 12 (237/272) | step 3230 | avg_nll=14.73 avg_ppl=7.70 speed=2590.77 words/sec time_elapsed=254.98 sec
# epoch 12 (247/272) | step 3240 | avg_nll=14.78 avg_ppl=7.84 speed=2717.02 words/sec time_elapsed=255.82 sec
# epoch 12 (257/272) | step 3250 | avg_nll=15.61 avg_ppl=8.35 speed=1757.42 words/sec time_elapsed=257.16 sec
# epoch 12 (267/272) | step 3260 | avg_nll=13.84 avg_ppl=6.83 speed=2689.66 words/sec time_elapsed=258.02 sec
# epoch 13 (5/272) | step 3270 | avg_nll=12.59 avg_ppl=5.81 speed=4137.68 words/sec time_elapsed=258.58 sec
# epoch 13 (15/272) | step 3280 | avg_nll=13.62 avg_ppl=6.40 speed=4333.12 words/sec time_elapsed=259.12 sec
# epoch 13 (25/272) | step 3290 | avg_nll=13.32 avg_ppl=6.52 speed=4143.68 words/sec time_elapsed=259.67 sec
# epoch 13 (35/272) | step 3300 | avg_nll=14.17 avg_ppl=7.15 speed=2984.66 words/sec time_elapsed=260.44 sec
# Begin validation ...
# validation: step 3300 | dev_ppl=10.099764823913574
# epoch 13 (45/272) | step 3310 | avg_nll=14.00 avg_ppl=6.83 speed=1989.58 words/sec time_elapsed=261.61 sec
# epoch 13 (55/272) | step 3320 | avg_nll=14.75 avg_ppl=7.49 speed=2622.76 words/sec time_elapsed=262.51 sec
# epoch 13 (65/272) | step 3330 | avg_nll=12.82 avg_ppl=6.09 speed=2868.66 words/sec time_elapsed=263.30 sec
# epoch 13 (75/272) | step 3340 | avg_nll=13.40 avg_ppl=6.39 speed=3978.71 words/sec time_elapsed=263.88 sec
# epoch 13 (85/272) | step 3350 | avg_nll=13.31 avg_ppl=6.39 speed=3945.74 words/sec time_elapsed=264.47 sec
# epoch 13 (95/272) | step 3360 | avg_nll=13.50 avg_ppl=6.55 speed=4253.52 words/sec time_elapsed=265.01 sec
# epoch 13 (105/272) | step 3370 | avg_nll=15.18 avg_ppl=8.00 speed=3994.44 words/sec time_elapsed=265.59 sec
# epoch 13 (115/272) | step 3380 | avg_nll=12.71 avg_ppl=6.01 speed=4204.36 words/sec time_elapsed=266.13 sec
# epoch 13 (125/272) | step 3390 | avg_nll=13.97 avg_ppl=6.89 speed=4081.32 words/sec time_elapsed=266.70 sec
# epoch 13 (135/272) | step 3400 | avg_nll=15.15 avg_ppl=7.71 speed=4110.37 words/sec time_elapsed=267.28 sec
# Begin validation ...
# validation: step 3400 | dev_ppl=9.69692325592041
# epoch 13 (145/272) | step 3410 | avg_nll=14.01 avg_ppl=6.89 speed=2772.31 words/sec time_elapsed=268.12 sec
# epoch 13 (155/272) | step 3420 | avg_nll=13.23 avg_ppl=6.31 speed=4062.22 words/sec time_elapsed=268.68 sec
# epoch 13 (165/272) | step 3430 | avg_nll=14.77 avg_ppl=7.59 speed=4118.99 words/sec time_elapsed=269.25 sec
# epoch 13 (175/272) | step 3440 | avg_nll=13.12 avg_ppl=6.15 speed=4106.68 words/sec time_elapsed=269.81 sec
# epoch 13 (185/272) | step 3450 | avg_nll=13.70 avg_ppl=6.87 speed=4093.97 words/sec time_elapsed=270.37 sec
# epoch 13 (195/272) | step 3460 | avg_nll=13.33 avg_ppl=6.38 speed=4141.24 words/sec time_elapsed=270.92 sec
# epoch 13 (205/272) | step 3470 | avg_nll=14.22 avg_ppl=7.26 speed=4151.86 words/sec time_elapsed=271.48 sec
# epoch 13 (215/272) | step 3480 | avg_nll=14.41 avg_ppl=7.07 speed=4069.07 words/sec time_elapsed=272.06 sec
# epoch 13 (225/272) | step 3490 | avg_nll=13.88 avg_ppl=6.59 speed=3899.97 words/sec time_elapsed=272.66 sec
# epoch 13 (235/272) | step 3500 | avg_nll=13.75 avg_ppl=6.73 speed=3951.56 words/sec time_elapsed=273.25 sec
# Begin validation ...
# validation: step 3500 | dev_ppl=9.455623626708984
# epoch 13 step 3500: save currently the best model to 'model.pt'
# epoch 13 (245/272) | step 3510 | avg_nll=14.86 avg_ppl=7.62 speed=1929.14 words/sec time_elapsed=274.46 sec
# epoch 13 (255/272) | step 3520 | avg_nll=14.41 avg_ppl=7.19 speed=3089.50 words/sec time_elapsed=275.22 sec
# epoch 13 (265/272) | step 3530 | avg_nll=13.47 avg_ppl=6.40 speed=2665.96 words/sec time_elapsed=276.09 sec
# epoch 14 (3/272) | step 3540 | avg_nll=14.05 avg_ppl=7.11 speed=2601.29 words/sec time_elapsed=276.97 sec
# epoch 14 (13/272) | step 3550 | avg_nll=13.87 avg_ppl=6.54 speed=4325.31 words/sec time_elapsed=277.52 sec
# epoch 14 (23/272) | step 3560 | avg_nll=12.25 avg_ppl=5.67 speed=4036.29 words/sec time_elapsed=278.08 sec
# epoch 14 (33/272) | step 3570 | avg_nll=13.78 avg_ppl=6.59 speed=4120.65 words/sec time_elapsed=278.65 sec
# epoch 14 (43/272) | step 3580 | avg_nll=12.96 avg_ppl=5.97 speed=4149.18 words/sec time_elapsed=279.21 sec
# epoch 14 (53/272) | step 3590 | avg_nll=12.83 avg_ppl=5.97 speed=4119.30 words/sec time_elapsed=279.76 sec
# epoch 14 (63/272) | step 3600 | avg_nll=13.65 avg_ppl=6.49 speed=4153.46 words/sec time_elapsed=280.33 sec
# Begin validation ...
# validation: step 3600 | dev_ppl=9.319258689880371
# epoch 14 step 3600: save currently the best model to 'model.pt'
# epoch 14 (73/272) | step 3610 | avg_nll=12.91 avg_ppl=6.13 speed=2751.75 words/sec time_elapsed=281.15 sec
# epoch 14 (83/272) | step 3620 | avg_nll=12.94 avg_ppl=6.04 speed=4265.88 words/sec time_elapsed=281.69 sec
# epoch 14 (93/272) | step 3630 | avg_nll=12.75 avg_ppl=5.99 speed=4081.69 words/sec time_elapsed=282.25 sec
# epoch 14 (103/272) | step 3640 | avg_nll=14.22 avg_ppl=6.84 speed=4400.93 words/sec time_elapsed=282.79 sec
# epoch 14 (113/272) | step 3650 | avg_nll=14.01 avg_ppl=6.77 speed=4398.66 words/sec time_elapsed=283.32 sec
# epoch 14 (123/272) | step 3660 | avg_nll=13.80 avg_ppl=6.69 speed=4153.10 words/sec time_elapsed=283.88 sec
# epoch 14 (133/272) | step 3670 | avg_nll=13.02 avg_ppl=6.04 speed=4206.66 words/sec time_elapsed=284.43 sec
# epoch 14 (143/272) | step 3680 | avg_nll=11.80 avg_ppl=5.24 speed=4263.14 words/sec time_elapsed=284.97 sec
# epoch 14 (153/272) | step 3690 | avg_nll=13.25 avg_ppl=6.02 speed=4153.16 words/sec time_elapsed=285.54 sec
# epoch 14 (163/272) | step 3700 | avg_nll=13.37 avg_ppl=6.30 speed=4024.03 words/sec time_elapsed=286.12 sec
# Begin validation ...
# validation: step 3700 | dev_ppl=9.539562225341797
# epoch 14 (173/272) | step 3710 | avg_nll=13.31 avg_ppl=6.26 speed=2838.65 words/sec time_elapsed=286.93 sec
# epoch 14 (183/272) | step 3720 | avg_nll=13.69 avg_ppl=6.61 speed=2954.45 words/sec time_elapsed=287.72 sec
# epoch 14 (193/272) | step 3730 | avg_nll=12.20 avg_ppl=5.42 speed=2896.95 words/sec time_elapsed=288.52 sec
# epoch 14 (203/272) | step 3740 | avg_nll=13.17 avg_ppl=6.06 speed=2868.93 words/sec time_elapsed=289.34 sec
# epoch 14 (213/272) | step 3750 | avg_nll=13.38 avg_ppl=6.34 speed=2730.82 words/sec time_elapsed=290.18 sec
# epoch 14 (223/272) | step 3760 | avg_nll=14.15 avg_ppl=7.21 speed=4088.72 words/sec time_elapsed=290.75 sec
# epoch 14 (233/272) | step 3770 | avg_nll=13.07 avg_ppl=6.15 speed=4244.17 words/sec time_elapsed=291.29 sec
# epoch 14 (243/272) | step 3780 | avg_nll=14.05 avg_ppl=7.02 speed=3946.62 words/sec time_elapsed=291.87 sec
# epoch 14 (253/272) | step 3790 | avg_nll=13.72 avg_ppl=6.39 speed=4470.15 words/sec time_elapsed=292.40 sec
# epoch 14 (263/272) | step 3800 | avg_nll=13.72 avg_ppl=6.57 speed=3908.53 words/sec time_elapsed=293.00 sec
# Begin validation ...
# validation: step 3800 | dev_ppl=9.012880325317383
# epoch 14 step 3800: save currently the best model to 'model.pt'
# epoch 15 (1/272) | step 3810 | avg_nll=13.38 avg_ppl=6.50 speed=2818.26 words/sec time_elapsed=293.81 sec
# epoch 15 (11/272) | step 3820 | avg_nll=13.30 avg_ppl=6.17 speed=4227.17 words/sec time_elapsed=294.36 sec
# epoch 15 (21/272) | step 3830 | avg_nll=12.24 avg_ppl=5.40 speed=4224.71 words/sec time_elapsed=294.92 sec
# epoch 15 (31/272) | step 3840 | avg_nll=12.86 avg_ppl=5.97 speed=4250.37 words/sec time_elapsed=295.46 sec
# epoch 15 (41/272) | step 3850 | avg_nll=12.76 avg_ppl=5.86 speed=4048.66 words/sec time_elapsed=296.03 sec
# epoch 15 (51/272) | step 3860 | avg_nll=11.99 avg_ppl=5.29 speed=4186.49 words/sec time_elapsed=296.58 sec
# epoch 15 (61/272) | step 3870 | avg_nll=11.64 avg_ppl=5.12 speed=4092.80 words/sec time_elapsed=297.14 sec
# epoch 15 (71/272) | step 3880 | avg_nll=12.30 avg_ppl=5.47 speed=4229.18 words/sec time_elapsed=297.69 sec
# epoch 15 (81/272) | step 3890 | avg_nll=12.45 avg_ppl=5.70 speed=4169.03 words/sec time_elapsed=298.23 sec
# epoch 15 (91/272) | step 3900 | avg_nll=13.04 avg_ppl=5.94 speed=4096.32 words/sec time_elapsed=298.81 sec
# Begin validation ...
# validation: step 3900 | dev_ppl=9.285974502563477
# epoch 15 (101/272) | step 3910 | avg_nll=13.02 avg_ppl=5.99 speed=2755.92 words/sec time_elapsed=299.65 sec
# epoch 15 (111/272) | step 3920 | avg_nll=12.26 avg_ppl=5.56 speed=3906.02 words/sec time_elapsed=300.24 sec
# epoch 15 (121/272) | step 3930 | avg_nll=12.80 avg_ppl=5.91 speed=2993.98 words/sec time_elapsed=301.01 sec
# epoch 15 (131/272) | step 3940 | avg_nll=13.71 avg_ppl=6.57 speed=3047.37 words/sec time_elapsed=301.78 sec
# epoch 15 (141/272) | step 3950 | avg_nll=13.02 avg_ppl=5.94 speed=2742.62 words/sec time_elapsed=302.63 sec
# epoch 15 (151/272) | step 3960 | avg_nll=12.77 avg_ppl=5.72 speed=2722.00 words/sec time_elapsed=303.49 sec
# epoch 15 (161/272) | step 3970 | avg_nll=12.42 avg_ppl=5.64 speed=4297.83 words/sec time_elapsed=304.03 sec
# epoch 15 (171/272) | step 3980 | avg_nll=13.80 avg_ppl=6.64 speed=4355.55 words/sec time_elapsed=304.56 sec
# epoch 15 (181/272) | step 3990 | avg_nll=14.46 avg_ppl=7.03 speed=4212.16 words/sec time_elapsed=305.12 sec
# epoch 15 (191/272) | step 4000 | avg_nll=12.08 avg_ppl=5.39 speed=4123.49 words/sec time_elapsed=305.68 sec
# Begin validation ...
# validation: step 4000 | dev_ppl=9.191712379455566
# epoch 15 (201/272) | step 4010 | avg_nll=12.51 avg_ppl=5.76 speed=2767.39 words/sec time_elapsed=306.51 sec
# epoch 15 (211/272) | step 4020 | avg_nll=13.31 avg_ppl=6.22 speed=3799.79 words/sec time_elapsed=307.12 sec
# epoch 15 (221/272) | step 4030 | avg_nll=12.66 avg_ppl=5.79 speed=4277.37 words/sec time_elapsed=307.66 sec
# epoch 15 (231/272) | step 4040 | avg_nll=12.99 avg_ppl=6.02 speed=4165.45 words/sec time_elapsed=308.22 sec
# epoch 15 (241/272) | step 4050 | avg_nll=12.25 avg_ppl=5.38 speed=4200.39 words/sec time_elapsed=308.77 sec
# epoch 15 (251/272) | step 4060 | avg_nll=13.80 avg_ppl=6.72 speed=4087.44 words/sec time_elapsed=309.34 sec
# epoch 15 (261/272) | step 4070 | avg_nll=13.26 avg_ppl=6.13 speed=4340.62 words/sec time_elapsed=309.88 sec
# epoch 15 (271/272) | step 4080 | avg_nll=11.98 avg_ppl=5.35 speed=4336.50 words/sec time_elapsed=310.41 sec
# Reached maximum number of epochs

# %% [markdown]
# ## Evaluate the model
#
# We have trained a seq2seq model for the NMT task. Now let's evaluate the model on the test set by generating translations with beam search and comparing them to the gold translations using the BLEU score.

# %%
from tqdm import tqdm
from nltk.translate.bleu_score import corpus_bleu

def beam_search(model: EncoderDecoderModel,
                encoder_input_ids: torch.LongTensor,
                beam_width: int = 5,
                max_len: int = 32) -> Tuple[torch.LongTensor, float]:
    """Run beam search on the encoder-decoder model for a single source sequence.

    Args:
        model: The encoder-decoder model.
        encoder_input_ids: The input sequence. Tensor of shape [encoder_sequence_length].
        beam_width: Number of generations to expand at each time step.
        max_len: Stop generation when reaching this length for the generated sequence.

    Returns:
        A tuple (generation, score) where generation is the generated target sequence and
            a tensor of shape [target_sequence_length] and score is the corresponding
            log-probability of this generation.
    """
    model.eval()

    encoder_input_ids = encoder_input_ids.unsqueeze(0) # Add the batch dimension
    encoder_padding_mask = torch.zeros_like(encoder_input_ids, dtype=torch.bool) # No padding
    encoder_outputs = model.forward_encoder(encoder_input_ids, encoder_padding_mask)

    generations = [torch.tensor([target_tokenizer.bos_token_id], device=encoder_input_ids.device)]
    scores = [0.0]

    best_generation = None
    best_score = float('-inf')

    for _ in range(max_len):
        new_generations = []
        new_scores = []
        for score, generation in zip(scores, generations):
            generation = generation.unsqueeze(0) # Add the batch dimension
            padding_mask = torch.zeros_like(generation, dtype=torch.bool) # No padding
            decoder_output = model.forward_decoder(generation, padding_mask, encoder_outputs, encoder_padding_mask)
            last_log_probs = decoder_output[0, -1, :].log_softmax(dim=-1)
            top_log_probs, top_indices = last_log_probs.topk(beam_width, dim=-1)

            new_generations.append(torch.cat([generation.expand(beam_width, -1), top_indices[:,None]], dim=1))
            new_scores.append(score + top_log_probs)

        new_generations = torch.cat(new_generations, dim=0)
        new_scores = torch.cat(new_scores, dim=0)

        ends_with_eos = target_tokenizer.eos_token_id == new_generations[:,-1]

        if ends_with_eos.any():
            new_completed_generations = new_generations[ends_with_eos]
            new_completed_scores = new_scores[ends_with_eos]

            if new_completed_scores.max() > best_score:
                best_score = new_completed_scores.max()
                best_generation = new_completed_generations[new_completed_scores.argmax()]

        if best_score >= new_scores.max():
            break

        scores, indices = torch.topk(new_scores, beam_width, dim=-1)
        generations = new_generations[indices]

    if best_generation is None:
        best_generation = generations[0]
        best_score = scores[0]

    return best_generation, best_score.cpu().item()


def run_generation(model, test_dataset, beam_size=5, max_decoding_time_step=32):
    """Run beam search decoding on the test set, compute BLEU and return reference and candidate target sentences.
    """

    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print('Use device: %s' % device)

    input_sentences = []
    reference_sentences = []
    candidate_sentences = []

    with torch.no_grad():
        for example in tqdm(test_dataset):
            encoder_input_ids = torch.tensor(example["encoder_input_ids"], device=device)

            generation, _ = beam_search(model, encoder_input_ids, beam_size, max_decoding_time_step)

            # Decode given source sequence and generated target sequence and avoid special tokens

            input_text = "".join(source_tokenizer.decode(token).replace("▁", " ") for token in example["encoder_input_ids"][1:-1])
            reference_text = "".join(target_tokenizer.decode(token).replace("▁", " ") for token in example["decoder_input_ids"][1:-1])
            candidate_text = "".join(target_tokenizer.decode(token).replace("▁", " ") for token in generation[1:-1].cpu())

            reference_sentences.append(reference_text)
            candidate_sentences.append(candidate_text)
            input_sentences.append(input_text)


    bleu_score = corpus_bleu([[ref] for ref in reference_sentences],
                             [candidate for candidate in candidate_sentences])

    return bleu_score, input_sentences, reference_sentences, candidate_sentences

# %%
# Restore the best validation checkpoint
model.load_state_dict(torch.load("model.pt"))

bleu_score, inputs, references, candidates = run_generation(model, tokenized_datasets["test"])
print('\n\nCorpus BLEU: {}'.format(bleu_score * 100))
# Out:
# Use device: cpu
# 100%|██████████| 486/486 [00:38<00:00, 12.70it/s]
# Corpus BLEU: 45.55735506670946

# %% [markdown]
# Let's look at some examples. What do you think of the quality of the translations?

# %%
# Feel free to change the range to look at more samples!
for k in range(10, 20):
  print(f"===== Sample {k} =====")
  print(f"Input: {inputs[k]}")
  print(f"Gold: {references[k]}")
  print(f"Pred: {candidates[k]}")
# Out:
# ===== Sample 10 =====
# Input:  vous me mettez mal a l aise .
# Gold:  you re embarrassing me .
# Pred:  i m waiting going to almost .
# ===== Sample 11 =====
# Input:  c est toi le professeur .
# Gold:  you re the teacher .
# Pred:  you re the teacher .
# ===== Sample 12 =====
# Input:  elle sourit avec bonheur .
# Gold:  she smiled happily .
# Pred:  she is certain him of him .
# ===== Sample 13 =====
# Input:  je ne suis pas devin .
# Gold:  i m not a psychic .
# Pred:  i m not asking .
# ===== Sample 14 =====
# Input:  vous allez perdre .
# Gold:  you re going to lose .
# Pred:  you re going back .
# ===== Sample 15 =====
# Input:  vous me touchez .
# Gold:  you re touching me .
# Pred:  you re nature .
# ===== Sample 16 =====
# Input:  je pars aujourd hui .
# Gold:  i m leaving today .
# Pred:  i m kidding .
# ===== Sample 17 =====
# Input:  je ne suis pas une sainte .
# Gold:  i m no saint .
# Pred:  i m not aist .
# ===== Sample 18 =====
# Input:  je suis puissant .
# Gold:  i m powerful .
# Pred:  i m good .
# ===== Sample 19 =====
# Input:  vous n etes qu un lache .
# Gold:  you re nothing but a coward .
# Pred:  you are not for a angry .

# %% [markdown]
# # Questions
#
# Please answer written questions from the assignment in this section. You can alter the provided code to obtain the answers, but be careful not to break anything!
#
# **(b) (4 points)**
#
# - (i)
#     What vocabulary size are we using for the source and target language?
#
# - (ii)
#     Approximately how many source and target tokens are on average contained in a training batch? What proportion of these tokens are `<pad>` tokens on average?
#
# - (iii)
# What is the specific purpose of saving the model parameters in a file `model.pt` throughout training in the code we provide?
#
# **(c) (2 points)**
# Manually look at some results and compare them with the gold answers. What do you think of the quality of the translations? Are these grammatical English sentences? Can you identify any common mistakes?
#
# **(d) (4 points)**
# Consider the provided beam search method. This implementation is not efficient and performs a lot of repeated computation. Identify the issue and propose how you can fix it.
# In particular, describe how would you have to change the arguments and return values of your EncoderDecoderModel and its sub-modules?

# %% [markdown]
# b) (i) 3200
#
# (ii)
#
# (iii) Saving the model parameters in a file (model.pt) throughout training allows us to:
#
#   1. Checkpointing: Saving the model parameters periodically during training allows you to save the current state of the model at regular intervals. This ensures that if the training process is interrupted due to any reason such as system failure, out-of-memory errors, or manual intervention, you can resume training from the last saved state rather than starting from scratch. This helps in saving computational resources and time.
#
#   1. Tracking Progress: Saving the model parameters along with other training-related information such as optimizer state, training statistics, and hyperparameters allows you to track the training progress over time. You can analyze the performance of the model at different stages of training and identify trends such as convergence, overfitting, or instability.
#
#   1. Model Deployment: Once the training is completed, the saved model parameters can be used for inference or deployment in production environments. By saving the model in a standardized format, such as PyTorch's state_dict, you ensure compatibility across different environments and systems.
#
# c) Overall, the quality of the translations is quite poor. Many of the predicted translations are grammatically incorrect and fail to capture the meaning of the original sentences. Common mistakes include mistranslations, incorrect word order, and grammatical errors.
#
# d) The provided beam search method suffers from inefficiency due to repeated computation of the encoder outputs and padding masks for each candidate generation. This inefficiency can be addressed by modifying the method to compute the encoder outputs and padding masks only once for the entire batch of input sequences and reuse them for all candidate generations.
#
#   1. Compute Encoder Outputs and Padding Masks Once: Instead of computing encoder outputs and padding masks for each candidate generation, compute them once for the entire batch of input sequences before the beam search loop. This eliminates the need for redundant computations.
#
#   1. Modify Encoder-Decoder Model Arguments and Return Values: Modify the arguments and return values of the EncoderDecoderModel and its sub-modules to accept and return batched input sequences and padding masks. This allows for efficient batch processing during inference.
#
#   1. Batch Processing: Modify the beam search method to perform batch processing by stacking input sequences and padding masks into batches. This allows for parallel computation of candidate generations, improving efficiency.

# %%
print(source_tokenizer.vocab_size)
print(target_tokenizer.vocab_size)
# Out:
# 3200
# 3200

# %%
# Initialize variables to accumulate statistics across all batches
total_source_tokens = 0
total_target_tokens = 0
total_source_padding = 0
total_target_padding = 0
num_batches = 0

# Iterate through all batches in the training data
for source_batch, target_batch in zip(source_train_data, target_train_data):
    # Analyze the current batch
    average_source_len, average_target_len, batch_source_padding, batch_target_padding = analyze_batch_tokens(source_batch, target_batch)

    # Update total counts
    total_source_tokens += average_source_len * len(source_batch)
    total_target_tokens += average_target_len * len(target_batch)
    total_source_padding += batch_source_padding
    total_target_padding += batch_target_padding
    num_batches += 1

# Calculate averages across all batches
average_source_tokens = total_source_tokens / (num_batches * batch_size)
average_target_tokens = total_target_tokens / (num_batches * batch_size)
proportion_source_padding = total_source_padding / total_source_tokens
proportion_target_padding = total_target_padding / total_target_tokens

# Print the results
print("Average number of source tokens in a training batch:", average_source_tokens)
print("Average number of target tokens in a training batch:", average_target_tokens)
print("Proportion of <pad> tokens in source batches on average:", proportion_source_padding)
print("Proportion of <pad> tokens in target batches on average:", proportion_target_padding)
# Out:
# Average number of source tokens in a training batch: 0.03125
# Average number of target tokens in a training batch: 0.03125
# Proportion of <pad> tokens in source batches on average: 0.0
# Proportion of <pad> tokens in target batches on average: 0.0
